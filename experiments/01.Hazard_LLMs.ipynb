# %%
import pandas as pd

# %%
# loadcleaned RASFF dataset
rasff = pd.read_csv(r"F:\Final_project\rasff_clean1.csv")

# %%
rasff['hazards']
# Out:
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3         Listeria monocytogenes
# 4               not in catalogue
#                    ...
# 27392     formaldehyde  migration
# 27393    Salmonella  enteritidis
# 27394               fosthiazate
# 27395            aflatoxin total
# 27396              Aflatoxins B1
# Name: hazards, Length: 27397, dtype: object

# %%
import openai
import os

# For environment variables (recommended for API key management)
from dotenv import load_dotenv
load_dotenv()

# Set up OpenAI client
client = openai.OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)


print("OpenAI client initialized successfully!")
# Out:
# OpenAI client initialized successfully!

# %%
hazard_categories = [
    "Microbiological",
    "Chemical (pesticides, metals)",
    "Mycotoxins",
    "Physical contaminants",
    "Migration from packaging",
    "Fraud/adulteration",
    "Allergen",
    "Others"
]

# %%
def classify_hazard(subject):
    prompt = f"""
You are a food safety expert. Categorize the following RASFF subject line into exactly ONE of these hazard categories:

Categories:
- Microbiological
- Chemical (pesticides, metals)
- Mycotoxins
- Physical contaminants
- Migration from packaging
- Fraud/adulteration
- Allergen
- Others

Below are examples for each category:

Microbiological:
1. "Suspected Salmonella in beef and hamburgers from Sweden"
2. "Listeria monocytogenes found in soft cheese from France"

Chemical (pesticides, metals):
1. "Food supplements from USA containing prohibited titanium dioxide"
2. "Excessive lead detected in curry powder from India"

Mycotoxins:
1. "Aflatoxin B1 found in peanuts from Argentina"
2. "Ochratoxin A detected in dried figs from Turkey"

Physical contaminants:
1. "Metal fragments found in chocolate bars"
2. "Glass pieces detected in jars of tomato sauce"

Migration from packaging:
1. "Bisphenol A migration from plastic food container"
2. "Primary aromatic amines migrating from printed packaging into noodles"

Fraud/adulteration:
1. "Label/document mismatch in instant noodles from South Korea"
2. "Extra virgin olive oil adulterated with cheaper seed oils"

Allergen:
1. "Undeclared milk in vegan protein snack"
2. "Presence of undeclared peanuts in chocolate cookies"

If the subject does not clearly fit any category, assign: "Others".

Now classify the following subject:

Subject: "{subject}"

Output only the category name.
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",   # recommended model
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    return response.choices[0].message.content.strip()

# %%
# Create a new column "Hazard_Category_LLM"
# WARNING: For large datasets, do this in chunks to avoid API rate limits
rasff['Hazard_Category_LLM'] = rasff['subject'].apply(classify_hazard)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Create a new column "Hazard_Category_LLM"
#       2 # WARNING: For large datasets, do this in chunks to avoid API rate limits
# ----> 3 rasff['Hazard_Category_LLM'] = rasff['subject'].apply(classify_hazard)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 54, in classify_hazard(subject)
#       1 def classify_hazard(subject):
#       2     prompt = f"""
#       3 You are a food safety expert. Categorize the following RASFF subject line into exactly ONE of these hazard categories:
#       4
#    (...)
#      51 Output only the category name.
#      52 """
# ---> 54     response = client.chat.completions.create(
#      55         model="gpt-4o-mini",   # recommended model
#      56         messages=[{"role": "user", "content": prompt}],
#      57         temperature=0
#      58     )
#      60     return response.choices[0].message.content.strip()
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\openai\resources\chat\completions\completions.py:1189, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1142 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1143 def create(
#    1144     self,
#    (...)
#    1186     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188     validate_response_format(response_format)
# -> 1189     return self._post(
#    1190         "/chat/completions",
#    1191         body=maybe_transform(
#    1192             {
#    1193                 "messages": messages,
#    1194                 "model": model,
#    1195                 "audio": audio,
#    1196                 "frequency_penalty": frequency_penalty,
#    1197                 "function_call": function_call,
#    1198                 "functions": functions,
#    1199                 "logit_bias": logit_bias,
#    1200                 "logprobs": logprobs,
#    1201                 "max_completion_tokens": max_completion_tokens,
#    1202                 "max_tokens": max_tokens,
#    1203                 "metadata": metadata,
#    1204                 "modalities": modalities,
#    1205                 "n": n,
#    1206                 "parallel_tool_calls": parallel_tool_calls,
#    1207                 "prediction": prediction,
#    1208                 "presence_penalty": presence_penalty,
#    1209                 "prompt_cache_key": prompt_cache_key,
#    1210                 "prompt_cache_retention": prompt_cache_retention,
#    1211                 "reasoning_effort": reasoning_effort,
#    1212                 "response_format": response_format,
#    1213                 "safety_identifier": safety_identifier,
#    1214                 "seed": seed,
#    1215                 "service_tier": service_tier,
#    1216                 "stop": stop,
#    1217                 "store": store,
#    1218                 "stream": stream,
#    1219                 "stream_options": stream_options,
#    1220                 "temperature": temperature,
#    1221                 "tool_choice": tool_choice,
#    1222                 "tools": tools,
#    1223                 "top_logprobs": top_logprobs,
#    1224                 "top_p": top_p,
#    1225                 "user": user,
#    1226                 "verbosity": verbosity,
#    1227                 "web_search_options": web_search_options,
#    1228             },
#    1229             completion_create_params.CompletionCreateParamsStreaming
#    1230             if stream
#    1231             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1232         ),
#    1233         options=make_request_options(
#    1234             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1235         ),
#    1236         cast_to=ChatCompletion,
#    1237         stream=stream or False,
#    1238         stream_cls=Stream[ChatCompletionChunk],
#    1239     )
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\SAMSUNG\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File c:\Users\SAMSUNG\anaconda3\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from openai import OpenAI
client = OpenAI()

def classify_batch(subject_list):
    # Join subjects into one multi-item prompt
    formatted = "\n".join([f"{i+1}. {s}" for i, s in enumerate(subject_list)])

    prompt = f"""

You are a food safety expert. Categorize the following RASFF subject line into exactly ONE of these hazard categories:

Categories:
- Microbiological
- Chemical (pesticides, metals)
- Mycotoxins
- Physical contaminants
- Migration from packaging
- Fraud/adulteration
- Allergen
- Others

Below are examples for each category:

Microbiological:
1. "Suspected Salmonella in beef and hamburgers from Sweden"
2. "Listeria monocytogenes found in soft cheese from France"

Chemical (pesticides, metals):
1. "Food supplements from USA containing prohibited titanium dioxide"
2. "Excessive lead detected in curry powder from India"

Mycotoxins:
1. "Aflatoxin B1 found in peanuts from Argentina"
2. "Ochratoxin A detected in dried figs from Turkey"

Physical contaminants:
1. "Metal fragments found in chocolate bars"
2. "Glass pieces detected in jars of tomato sauce"

Migration from packaging:
1. "Bisphenol A migration from plastic food container"
2. "Primary aromatic amines migrating from printed packaging into noodles"

Fraud/adulteration:
1. "Label/document mismatch in instant noodles from South Korea"
2. "Extra virgin olive oil adulterated with cheaper seed oils"

Allergen:
1. "Undeclared milk in vegan protein snack"
2. "Presence of undeclared peanuts in chocolate cookies"

If the subject does not clearly fit any category, assign: "Others".

Now classify the following subject:

Subject: "{formatted}"

Return the output as a numbered list with only the category per line.
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    # Split output into list of categories
    output = response.choices[0].message.content.strip().split("\n")
    output = [line.split(". ", 1)[1] for line in output]
    return output


# Process in batches
batch_size = 50
results = []

subjects = rasff["subject"].tolist()

for i in range(0, len(subjects), batch_size):
    batch = subjects[i:i + batch_size]
    categories = classify_batch(batch)
    results.extend(categories)
    print(f"Processed {i + len(batch)} items")

rasff["Hazard_Category_LLM"] = results
# Out:
# Processed 50 items
# Processed 100 items
# Processed 150 items
# Processed 200 items
# Processed 250 items
# Processed 300 items
# Processed 350 items
# Processed 400 items
# Processed 450 items
# Processed 500 items
# Processed 550 items
# Processed 600 items
# Processed 650 items
# Processed 700 items
# Processed 750 items
# Processed 800 items
# Processed 850 items
# Processed 900 items
# Processed 950 items
# Processed 1000 items
# Processed 1050 items
# Processed 1100 items
# Processed 1150 items
# Processed 1200 items
# Processed 1250 items
# Processed 1300 items
# Processed 1350 items
# Processed 1400 items
# Processed 1450 items
# Processed 1500 items
# Processed 1550 items
# Processed 1600 items
# Processed 1650 items
# Processed 1700 items
# Processed 1750 items
# Processed 1800 items
# Processed 1850 items
# Processed 1900 items
# Processed 1950 items
# Processed 2000 items
# Processed 2050 items
# Processed 2100 items
# Processed 2150 items
# Processed 2200 items
# Processed 2250 items
# Processed 2300 items
# Processed 2350 items
# Processed 2400 items
# Processed 2450 items
# Processed 2500 items
# Processed 2550 items
# Processed 2600 items
# Processed 2650 items
# Processed 2700 items
# Processed 2750 items
# Processed 2800 items
# Processed 2850 items
# Processed 2900 items
# Processed 2950 items
# Processed 3000 items
# Processed 3050 items
# Processed 3100 items
# Processed 3150 items
# Processed 3200 items
# Processed 3250 items
# Processed 3300 items
# Processed 3350 items
# Processed 3400 items
# Processed 3450 items
# Processed 3500 items
# Processed 3550 items
# Processed 3600 items
# Processed 3650 items
# Processed 3700 items
# Processed 3750 items
# Processed 3800 items
# Processed 3850 items
# Processed 3900 items
# Processed 3950 items
# Processed 4000 items
# Processed 4050 items
# Processed 4100 items
# Processed 4150 items
# Processed 4200 items
# Processed 4250 items
# Processed 4300 items
# Processed 4350 items
# Processed 4400 items
# Processed 4450 items
# Processed 4500 items
# Processed 4550 items
# Processed 4600 items
# Processed 4650 items
# Processed 4700 items
# Processed 4750 items
# Processed 4800 items
# Processed 4850 items
# Processed 4900 items
# Processed 4950 items
# Processed 5000 items
# Processed 5050 items
# Processed 5100 items
# Processed 5150 items
# Processed 5200 items
# Processed 5250 items
# Processed 5300 items
# Processed 5350 items
# Processed 5400 items
# Processed 5450 items
# Processed 5500 items
# Processed 5550 items
# Processed 5600 items
# Processed 5650 items
# Processed 5700 items
# Processed 5750 items
# Processed 5800 items
# Processed 5850 items
# Processed 5900 items
# Processed 5950 items
# Processed 6000 items
# Processed 6050 items
# Processed 6100 items
# Processed 6150 items
# Processed 6200 items
# Processed 6250 items
# Processed 6300 items
# Processed 6350 items
# Processed 6400 items
# Processed 6450 items
# Processed 6500 items
# Processed 6550 items
# Processed 6600 items
# Processed 6650 items
# Processed 6700 items
# Processed 6750 items
# Processed 6800 items
# Processed 6850 items
# Processed 6900 items
# Processed 6950 items
# Processed 7000 items
# Processed 7050 items
# Processed 7100 items
# Processed 7150 items
# Processed 7200 items
# Processed 7250 items
# Processed 7300 items
# Processed 7350 items
# Processed 7400 items
# Processed 7450 items
# Processed 7500 items
# Processed 7550 items
# Processed 7600 items
# Processed 7650 items
# Processed 7700 items
# Processed 7750 items
# Processed 7800 items
# Processed 7850 items
# Processed 7900 items
# Processed 7950 items
# Processed 8000 items
# Processed 8050 items
# Processed 8100 items
# Processed 8150 items
# Processed 8200 items
# Processed 8250 items
# Processed 8300 items
# Processed 8350 items
# Processed 8400 items
# Processed 8450 items
# Processed 8500 items
# Processed 8550 items
# Processed 8600 items
# Processed 8650 items
# Processed 8700 items
# Processed 8750 items
# Processed 8800 items
# Processed 8850 items
# Processed 8900 items
# Processed 8950 items
# Processed 9000 items
# Processed 9050 items
# Processed 9100 items
# Processed 9150 items
# Processed 9200 items
# Processed 9250 items
# Processed 9300 items
# Processed 9350 items
# Processed 9400 items
# Processed 9450 items
# Processed 9500 items
# Processed 9550 items
# Processed 9600 items
# Processed 9650 items
# Processed 9700 items
# Processed 9750 items
# Processed 9800 items
# Processed 9850 items
# Processed 9900 items
# Processed 9950 items
# Processed 10000 items
# Processed 10050 items
# Processed 10100 items
# Processed 10150 items
# Processed 10200 items
# Processed 10250 items
# Processed 10300 items
# Processed 10350 items
# Processed 10400 items
# Processed 10450 items
# Processed 10500 items
# Processed 10550 items
# Processed 10600 items
# Processed 10650 items
# Processed 10700 items
# Processed 10750 items
# Processed 10800 items
# Processed 10850 items
# Processed 10900 items
# Processed 10950 items
# Processed 11000 items
# Processed 11050 items
# Processed 11100 items
# Processed 11150 items
# Processed 11200 items
# Processed 11250 items
# Processed 11300 items
# Processed 11350 items
# Processed 11400 items
# Processed 11450 items
# Processed 11500 items
# Processed 11550 items
# Processed 11600 items
# Processed 11650 items
# Processed 11700 items
# Processed 11750 items
# Processed 11800 items
# Processed 11850 items
# Processed 11900 items
# Processed 11950 items
# Processed 12000 items
# Processed 12050 items
# Processed 12100 items
# Processed 12150 items
# Processed 12200 items
# Processed 12250 items
# Processed 12300 items
# Processed 12350 items
# Processed 12400 items
# Processed 12450 items
# Processed 12500 items
# Processed 12550 items
# Processed 12600 items
# Processed 12650 items
# Processed 12700 items
# Processed 12750 items
# Processed 12800 items
# Processed 12850 items
# Processed 12900 items
# Processed 12950 items
# Processed 13000 items
# Processed 13050 items
# Processed 13100 items
# Processed 13150 items
# Processed 13200 items
# Processed 13250 items
# Processed 13300 items
# Processed 13350 items
# Processed 13400 items
# Processed 13450 items
# Processed 13500 items
# Processed 13550 items
# Processed 13600 items
# Processed 13650 items
# Processed 13700 items
# Processed 13750 items
# Processed 13800 items
# Processed 13850 items
# Processed 13900 items
# Processed 13950 items
# Processed 14000 items
# Processed 14050 items
# Processed 14100 items
# Processed 14150 items
# Processed 14200 items
# Processed 14250 items
# Processed 14300 items
# Processed 14350 items
# Processed 14400 items
# Processed 14450 items
# Processed 14500 items
# Processed 14550 items
# Processed 14600 items
# Processed 14650 items
# Processed 14700 items
# Processed 14750 items
# Processed 14800 items
# Processed 14850 items
# Processed 14900 items
# Processed 14950 items
# Processed 15000 items
# Processed 15050 items
# Processed 15100 items
# Processed 15150 items
# Processed 15200 items
# Processed 15250 items
# Processed 15300 items
# Processed 15350 items
# Processed 15400 items
# Processed 15450 items
# Processed 15500 items
# Processed 15550 items
# Processed 15600 items
# Processed 15650 items
# Processed 15700 items
# Processed 15750 items
# Processed 15800 items
# Processed 15850 items
# Processed 15900 items
# Processed 15950 items
# Processed 16000 items
# Processed 16050 items
# Processed 16100 items
# Processed 16150 items
# Processed 16200 items
# Processed 16250 items
# Processed 16300 items
# Processed 16350 items
# Processed 16400 items
# Processed 16450 items
# Processed 16500 items
# Processed 16550 items
# Processed 16600 items
# Processed 16650 items
# Processed 16700 items
# Processed 16750 items
# Processed 16800 items
# Processed 16850 items
# Processed 16900 items
# Processed 16950 items
# Processed 17000 items
# Processed 17050 items
# Processed 17100 items
# Processed 17150 items
# Processed 17200 items
# Processed 17250 items
# Processed 17300 items
# Processed 17350 items
# Processed 17400 items
# Processed 17450 items
# Processed 17500 items
# Processed 17550 items
# Processed 17600 items
# Processed 17650 items
# Processed 17700 items
# Processed 17750 items
# Processed 17800 items
# Processed 17850 items
# Processed 17900 items
# Processed 17950 items
# Processed 18000 items
# Processed 18050 items
# Processed 18100 items
# Processed 18150 items
# Processed 18200 items
# Processed 18250 items
# Processed 18300 items
# Processed 18350 items
# Processed 18400 items
# Processed 18450 items
# Processed 18500 items
# Processed 18550 items
# Processed 18600 items
# Processed 18650 items
# Processed 18700 items
# Processed 18750 items
# Processed 18800 items
# Processed 18850 items
# Processed 18900 items
# Processed 18950 items
# Processed 19000 items
# Processed 19050 items
# Processed 19100 items
# Processed 19150 items
# Processed 19200 items
# Processed 19250 items
# Processed 19300 items
# Processed 19350 items
# Processed 19400 items
# Processed 19450 items
# Processed 19500 items
# Processed 19550 items
# Processed 19600 items
# Processed 19650 items
# Processed 19700 items
# Processed 19750 items
# Processed 19800 items
# Processed 19850 items
# Processed 19900 items
# Processed 19950 items
# Processed 20000 items
# Processed 20050 items
# Processed 20100 items
# Processed 20150 items
# Processed 20200 items
# Processed 20250 items
# Processed 20300 items
# Processed 20350 items
# Processed 20400 items
# Processed 20450 items
# Processed 20500 items
# Processed 20550 items
# Processed 20600 items
# Processed 20650 items
# Processed 20700 items
# Processed 20750 items
# Processed 20800 items
# Processed 20850 items
# Processed 20900 items
# Processed 20950 items
# Processed 21000 items
# Processed 21050 items
# Processed 21100 items
# Processed 21150 items
# Processed 21200 items
# Processed 21250 items
# Processed 21300 items
# Processed 21350 items
# Processed 21400 items
# Processed 21450 items
# Processed 21500 items
# Processed 21550 items
# Processed 21600 items
# Processed 21650 items
# Processed 21700 items
# Processed 21750 items
# Processed 21800 items
# Processed 21850 items
# Processed 21900 items
# Processed 21950 items
# Processed 22000 items
# Processed 22050 items
# Processed 22100 items
# Processed 22150 items
# Processed 22200 items
# Processed 22250 items
# Processed 22300 items
# Processed 22350 items
# Processed 22400 items
# Processed 22450 items
# Processed 22500 items
# Processed 22550 items
# Processed 22600 items
# Processed 22650 items
# Processed 22700 items
# Processed 22750 items
# Processed 22800 items
# Processed 22850 items
# Processed 22900 items
# Processed 22950 items
# Processed 23000 items
# Processed 23050 items
# Processed 23100 items
# Processed 23150 items
# Processed 23200 items
# Processed 23250 items
# Processed 23300 items
# Processed 23350 items
# Processed 23400 items
# Processed 23450 items
# Processed 23500 items
# Processed 23550 items
# Processed 23600 items
# Processed 23650 items
# Processed 23700 items
# Processed 23750 items
# Processed 23800 items
# Processed 23850 items
# Processed 23900 items
# Processed 23950 items
# Processed 24000 items
# Processed 24050 items
# Processed 24100 items
# Processed 24150 items
# Processed 24200 items
# Processed 24250 items
# Processed 24300 items
# Processed 24350 items
# Processed 24400 items
# Processed 24450 items
# Processed 24500 items
# Processed 24550 items
# Processed 24600 items
# Processed 24650 items
# Processed 24700 items
# Processed 24750 items
# Processed 24800 items
# Processed 24850 items
# Processed 24900 items
# Processed 24950 items
# Processed 25000 items
# Processed 25050 items
# Processed 25100 items
# Processed 25150 items
# Processed 25200 items
# Processed 25250 items
# Processed 25300 items
# Processed 25350 items
# Processed 25400 items
# Processed 25450 items
# Processed 25500 items
# Processed 25550 items
# Processed 25600 items
# Processed 25650 items
# Processed 25700 items
# Processed 25750 items
# Processed 25800 items
# Processed 25850 items
# Processed 25900 items
# Processed 25950 items
# Processed 26000 items
# Processed 26050 items
# Processed 26100 items
# Processed 26150 items
# Processed 26200 items
# Processed 26250 items
# Processed 26300 items
# Processed 26350 items
# Processed 26400 items
# Processed 26450 items
# Processed 26500 items
# Processed 26550 items
# Processed 26600 items
# Processed 26650 items
# Processed 26700 items
# Processed 26750 items
# Processed 26800 items
# Processed 26850 items
# Processed 26900 items
# Processed 26950 items
# Processed 27000 items
# Processed 27050 items
# Processed 27100 items
# Processed 27150 items
# Processed 27200 items
# Processed 27250 items
# Processed 27300 items
# Processed 27350 items
# Processed 27397 items

# %%
rasff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27397 entries, 0 to 27396
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   reference            27397 non-null  float64
#  1   category             27397 non-null  object
#  2   type                 27397 non-null  object
#  3   subject              27397 non-null  object
#  4   date                 27397 non-null  object
#  5   notifying_country    27397 non-null  object
#  6   classification       27397 non-null  object
#  7   risk_decision        27397 non-null  object
#  8   distribution         18759 non-null  object
#  9   forAttention         14966 non-null  object
#  10  forFollowUp          13810 non-null  object
#  11  operator             27303 non-null  object
#  12  origin               26823 non-null  object
#  13  hazards              20241 non-null  object
#  14  year                 27397 non-null  int64
#  15  month                27397 non-null  int64
#  16  Hazard_Category_LLM  27397 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 3.6+ MB

# %%
rasff['Hazard_Category_LLM']
# Out:
# 0                        Microbiological
# 1                                 Others
# 2          Chemical (pesticides, metals)
# 3                        Microbiological
# 4                                 Others
#                       ...
# 27392         Migration from packaging
# 27393                  Microbiological
# 27394    Chemical (pesticides, metals)
# 27395                       Mycotoxins
# 27396                         Mycotoxins
# Name: Hazard_Category_LLM, Length: 27397, dtype: object

# %%
rasff.to_csv("rasff_clean2.csv", index=False)

# %%
rasff['Hazard_Category_LLM'].value_counts()
# Out:
# Hazard_Category_LLM
# Chemical (pesticides, metals)            6430
# Microbiological                          4632
# Others                                   3222
# Chemical (pesticides, metals)            2951
# Mycotoxins                               2356
# Microbiological                          1958
# Others                                   1304
# Mycotoxins                                971
# Allergen                                  862
# Physical contaminants                     789
# Migration from packaging                  556
# Allergen                                  370
# Fraud/adulteration                        352
# Physical contaminants                     281
# Migration from packaging                  233
# Fraud/adulteration                        124
# Chemical (migration from packaging)         6
# Name: count, dtype: int64

# %%
# loadcleaned RASFF dataset
rasff = pd.read_csv(r"F:\Final_project\rasff_clean2.csv")

# %%
rasff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27397 entries, 0 to 27396
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   reference            27397 non-null  float64
#  1   category             27397 non-null  object
#  2   type                 27397 non-null  object
#  3   subject              27397 non-null  object
#  4   date                 27397 non-null  object
#  5   notifying_country    27397 non-null  object
#  6   classification       27397 non-null  object
#  7   risk_decision        27397 non-null  object
#  8   distribution         18759 non-null  object
#  9   forAttention         14966 non-null  object
#  10  forFollowUp          13810 non-null  object
#  11  operator             27303 non-null  object
#  12  origin               26823 non-null  object
#  13  hazards              20241 non-null  object
#  14  year                 27397 non-null  int64
#  15  month                27397 non-null  int64
#  16  Hazard_Category_LLM  27397 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 3.6+ MB

# %%
rasff['Hazard_Category_LLM'].nunique()
# Out:
# 17

# %%
for c in rasff['Hazard_Category_LLM'].unique():
    print(repr(c))
# Out:
# 'Microbiological'
# 'Others'
# 'Chemical (pesticides, metals)'
# 'Allergen'
# 'Mycotoxins'
# 'Migration from packaging'
# 'Physical contaminants  '
# 'Others  '
# 'Microbiological  '
# 'Allergen  '
# 'Chemical (pesticides, metals)  '
# 'Mycotoxins  '
# 'Fraud/adulteration  '
# 'Fraud/adulteration'
# 'Migration from packaging  '
# 'Physical contaminants'
# 'Chemical (migration from packaging)  '

# %%
rasff['len'] = rasff['Hazard_Category_LLM'].apply(len)
rasff[['Hazard_Category_LLM','len']].drop_duplicates()
# Out:
#                         Hazard_Category_LLM  len
# 0                           Microbiological   15
# 1                                    Others    6
# 2             Chemical (pesticides, metals)   29
# 5                                  Allergen    8
# 12                               Mycotoxins   10
# 13                 Migration from packaging   24
# 50                  Physical contaminants     23
# 51                                 Others      8
# 54                        Microbiological     17
# 56                               Allergen     10
# 58          Chemical (pesticides, metals)     31
# 64                             Mycotoxins     12
# 122                    Fraud/adulteration     20
# 149                      Fraud/adulteration   18
# 151              Migration from packaging     26
# 218                   Physical contaminants   21
# 4127  Chemical (migration from packaging)     37

# %%
import unicodedata
import re

def clean_text(x):
    if not isinstance(x, str):
        return x

    # Normalize unicode
    x = unicodedata.normalize("NFKC", x)

    # Remove zero-width characters
    x = re.sub(r"[\u200B-\u200D\uFEFF]", "", x)

    # Collapse all whitespace including NBSPs
    x = " ".join(x.split())

    return x.strip()

rasff["Hazard_Category_LLM"] = rasff["Hazard_Category_LLM"].apply(clean_text)

# %%
rasff['Hazard_Category_LLM'].value_counts()
# Out:
# Hazard_Category_LLM
# Chemical (pesticides, metals)          9381
# Microbiological                        6590
# Others                                 4526
# Mycotoxins                             3327
# Allergen                               1232
# Physical contaminants                  1070
# Migration from packaging                789
# Fraud/adulteration                      476
# Chemical (migration from packaging)       6
# Name: count, dtype: int64

# %%
rasff['Hazard_Category_LLM'] = rasff['Hazard_Category_LLM'].replace(
    {'Chemical (migration from packaging)': 'Migration from packaging'}
)

# %%
rasff['Hazard_Category_LLM'].value_counts()
# Out:
# Hazard_Category_LLM
# Chemical (pesticides, metals)    9381
# Microbiological                  6590
# Others                           4526
# Mycotoxins                       3327
# Allergen                         1232
# Physical contaminants            1070
# Migration from packaging          795
# Fraud/adulteration                476
# Name: count, dtype: int64

# %%
rasff.to_csv("rasff_clean3.csv", index=False)

# %%
# loadcleaned RASFF dataset
rasff = pd.read_csv(r"F:\Final_project\rasff_clean3.csv")

# %%
rasff['Hazard_Category_LLM'].value_counts()
# Out:
# Hazard_Category_LLM
# Chemical (pesticides, metals)    9381
# Microbiological                  6590
# Others                           4526
# Mycotoxins                       3327
# Allergen                         1232
# Physical contaminants            1070
# Migration from packaging          795
# Fraud/adulteration                476
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top_hazards = rasff['Hazard_Category_LLM'].value_counts()
plt.figure(figsize=(12,6))
sns.barplot(x=top_hazards.values, y=top_hazards.index, palette='Spectral')
plt.title("Top 10 Reported Hazards in RASFF")
plt.xlabel("Number of Notifications")
plt.ylabel("Hazard")
plt.show()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_17596\2338271717.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_hazards.values, y=top_hazards.index, palette='Spectral')

# %% [markdown]
# ### Solving the issue with others/add new category novel food

# %%
from openai import OpenAI
import pandas as pd
from tqdm import tqdm

client = OpenAI()

# Updated list of categories
CATEGORIES = [
    "Microbiological",
    "Chemical (pesticides, metals)",
    "Mycotoxins",
    "Physical contaminants",
    "Migration from packaging",
    "Fraud/adulteration",
    "Allergen",
    "Novel food",
    "Others"
]

def classify_batch(subject_list):
    # Format numbered list for batch
    formatted = "\n".join([f"{i+1}. {s}" for i, s in enumerate(subject_list)])

    # Prompt with examples (same as your original, plus "Novel food" category added)
    prompt = f"""
You are a food safety expert. Categorize the following RASFF subject lines into exactly ONE of these hazard categories:

Categories:
- Microbiological
- Chemical (pesticides, metals)
- Mycotoxins
- Physical contaminants
- Migration from packaging
- Fraud/adulteration
- Allergen
- Novel food
- Others

Below are examples for each category:

Microbiological:
1. "Suspected Salmonella in beef and hamburgers from Sweden"
2. "Listeria monocytogenes found in soft cheese from France"

Chemical (pesticides, metals):
1. "Food supplements from USA containing prohibited titanium dioxide"
2. "Excessive lead detected in curry powder from India"

Mycotoxins:
1. "Aflatoxin B1 found in peanuts from Argentina"
2. "Ochratoxin A detected in dried figs from Turkey"

Physical contaminants:
1. "Metal fragments found in chocolate bars"
2. "Glass pieces detected in jars of tomato sauce"

Migration from packaging:
1. "Bisphenol A migration from plastic food container"
2. "Primary aromatic amines migrating from printed packaging into noodles"

Fraud/adulteration:
1. "Label/document mismatch in instant noodles from South Korea"
2. "Extra virgin olive oil adulterated with cheaper seed oils"

Allergen:
1. "Undeclared milk in vegan protein snack"
2. "Presence of undeclared peanuts in chocolate cookies"

Novel food:
1. "Novel food (DMAE) in food supplements from China"
2. "Tonka beans - non authorized Novel Food"
3. "Unapproved novel food ingredient in snack"

If the subject does not clearly fit any category, assign: "Others".

Now classify the following subjects:

Subject:
"{formatted}"

Return the output as a numbered list with only the category per line. Only return categories from the list above.
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    # Split output and validate categories
    output = response.choices[0].message.content.strip().split("\n")
    cleaned_output = []
    for line in output:
        if ". " in line:
            cat = line.split(". ", 1)[1].strip()
        else:
            cat = line.strip()
        # fallback to "Others" if category is invalid
        if cat not in CATEGORIES:
            cat = "Others"
        cleaned_output.append(cat)

    return cleaned_output

# %%
# -------------------------------
# Reclassify only "Others" and "Fraud/adulteration"
# -------------------------------
mask_to_reclassify = rasff["Hazard_Category_LLM"].isin(["Others", "Fraud/adulteration"])
df_to_reclassify = rasff[mask_to_reclassify].copy()
subjects_to_reclassify = df_to_reclassify["subject"].tolist()

batch_size = 50
reclassified = []

for i in tqdm(range(0, len(subjects_to_reclassify), batch_size)):
    batch = subjects_to_reclassify[i:i + batch_size]
    batch_categories = classify_batch(batch)
    reclassified.extend(batch_categories)
    print(f"Processed {i + len(batch)} items")

# Update dataframe
rasff.loc[mask_to_reclassify, "Hazard_Category_LLM"] = reclassified

# Check results
print(rasff["Hazard_Category_LLM"].value_counts())
# Out:
#   1%|          | 1/101 [00:06<11:03,  6.64s/it]
# Processed 50 items
#   2%|▏         | 2/101 [00:13<11:25,  6.92s/it]
# Processed 100 items
#   3%|▎         | 3/101 [00:20<11:21,  6.95s/it]
# Processed 150 items
#   4%|▍         | 4/101 [00:26<10:39,  6.59s/it]
# Processed 200 items
#   5%|▍         | 5/101 [00:34<11:01,  6.89s/it]
# Processed 250 items
#   6%|▌         | 6/101 [00:39<10:08,  6.41s/it]
# Processed 300 items
#   7%|▋         | 7/101 [00:46<10:16,  6.56s/it]
# Processed 350 items
#   8%|▊         | 8/101 [00:52<09:55,  6.40s/it]
# Processed 400 items
#   9%|▉         | 9/101 [00:59<09:56,  6.49s/it]
# Processed 450 items
#  10%|▉         | 10/101 [01:05<09:52,  6.51s/it]
# Processed 500 items
#  11%|█         | 11/101 [01:14<10:33,  7.03s/it]
# Processed 550 items
#  12%|█▏        | 12/101 [01:21<10:46,  7.27s/it]
# Processed 600 items
#  13%|█▎        | 13/101 [01:27<10:04,  6.87s/it]
# Processed 650 items
#  14%|█▍        | 14/101 [01:35<10:22,  7.16s/it]
# Processed 700 items
#  15%|█▍        | 15/101 [01:42<10:18,  7.19s/it]
# Processed 750 items
#  16%|█▌        | 16/101 [01:49<10:05,  7.12s/it]
# Processed 800 items
#  17%|█▋        | 17/101 [01:57<10:11,  7.28s/it]
# Processed 850 items
#  18%|█▊        | 18/101 [02:04<09:51,  7.13s/it]
# Processed 900 items
#  19%|█▉        | 19/101 [02:12<10:14,  7.50s/it]
# Processed 950 items
#  20%|█▉        | 20/101 [02:20<10:07,  7.50s/it]
# Processed 1000 items
#  21%|██        | 21/101 [02:27<09:48,  7.35s/it]
# Processed 1050 items
#  22%|██▏       | 22/101 [02:33<09:26,  7.17s/it]
# Processed 1100 items
#  23%|██▎       | 23/101 [02:41<09:31,  7.33s/it]
# Processed 1150 items
#  24%|██▍       | 24/101 [02:48<09:05,  7.08s/it]
# Processed 1200 items
#  25%|██▍       | 25/101 [02:56<09:23,  7.42s/it]
# Processed 1250 items
#  26%|██▌       | 26/101 [03:02<08:50,  7.07s/it]
# Processed 1300 items
#  27%|██▋       | 27/101 [03:09<08:42,  7.06s/it]
# Processed 1350 items
#  28%|██▊       | 28/101 [03:18<09:11,  7.55s/it]
# Processed 1400 items
#  29%|██▊       | 29/101 [03:24<08:29,  7.08s/it]
# Processed 1450 items
#  30%|██▉       | 30/101 [03:30<07:57,  6.73s/it]
# Processed 1500 items
#  31%|███       | 31/101 [03:37<07:55,  6.79s/it]
# Processed 1550 items
#  32%|███▏      | 32/101 [03:43<07:39,  6.66s/it]
# Processed 1600 items
#  33%|███▎      | 33/101 [03:51<07:54,  6.98s/it]
# Processed 1650 items
#  34%|███▎      | 34/101 [03:57<07:24,  6.63s/it]
# Processed 1700 items
#  35%|███▍      | 35/101 [04:03<07:22,  6.71s/it]
# Processed 1750 items
#  36%|███▌      | 36/101 [04:10<07:05,  6.55s/it]
# Processed 1800 items
#  37%|███▋      | 37/101 [04:18<07:35,  7.12s/it]
# Processed 1850 items
#  38%|███▊      | 38/101 [04:25<07:23,  7.05s/it]
# Processed 1900 items
#  39%|███▊      | 39/101 [04:33<07:33,  7.32s/it]
# Processed 1950 items
#  40%|███▉      | 40/101 [04:40<07:19,  7.20s/it]
# Processed 2000 items
#  41%|████      | 41/101 [04:46<06:52,  6.87s/it]
# Processed 2050 items
#  42%|████▏     | 42/101 [04:52<06:38,  6.76s/it]
# Processed 2100 items
#  43%|████▎     | 43/101 [04:59<06:26,  6.67s/it]
# Processed 2150 items
#  44%|████▎     | 44/101 [05:06<06:19,  6.66s/it]
# Processed 2200 items
#  45%|████▍     | 45/101 [05:11<05:57,  6.38s/it]
# Processed 2250 items
#  46%|████▌     | 46/101 [05:18<05:49,  6.36s/it]
# Processed 2300 items
#  47%|████▋     | 47/101 [05:24<05:47,  6.43s/it]
# Processed 2350 items
#  48%|████▊     | 48/101 [05:31<05:50,  6.62s/it]
# Processed 2400 items
#  49%|████▊     | 49/101 [05:37<05:27,  6.30s/it]
# Processed 2450 items
#  50%|████▉     | 50/101 [05:42<05:05,  6.00s/it]
# Processed 2500 items
#  50%|█████     | 51/101 [05:51<05:40,  6.81s/it]
# Processed 2550 items
#  51%|█████▏    | 52/101 [05:58<05:44,  7.04s/it]
# Processed 2600 items
#  52%|█████▏    | 53/101 [06:05<05:26,  6.81s/it]
# Processed 2650 items
#  53%|█████▎    | 54/101 [06:12<05:30,  7.03s/it]
# Processed 2700 items
#  54%|█████▍    | 55/101 [06:21<05:47,  7.56s/it]
# Processed 2750 items
#  55%|█████▌    | 56/101 [06:28<05:34,  7.44s/it]
# Processed 2800 items
#  56%|█████▋    | 57/101 [06:34<05:12,  7.09s/it]
# Processed 2850 items
#  57%|█████▋    | 58/101 [06:41<04:53,  6.83s/it]
# Processed 2900 items
#  58%|█████▊    | 59/101 [06:47<04:45,  6.80s/it]
# Processed 2950 items
#  59%|█████▉    | 60/101 [06:53<04:26,  6.50s/it]
# Processed 3000 items
#  60%|██████    | 61/101 [07:00<04:27,  6.68s/it]
# Processed 3050 items
#  61%|██████▏   | 62/101 [07:08<04:28,  6.88s/it]
# Processed 3100 items
#  62%|██████▏   | 63/101 [07:14<04:14,  6.71s/it]
# Processed 3150 items
#  63%|██████▎   | 64/101 [07:20<04:02,  6.54s/it]
# Processed 3200 items
#  64%|██████▍   | 65/101 [07:25<03:39,  6.10s/it]
# Processed 3250 items
#  65%|██████▌   | 66/101 [07:32<03:40,  6.31s/it]
# Processed 3300 items
#  66%|██████▋   | 67/101 [07:40<03:47,  6.70s/it]
# Processed 3350 items
#  67%|██████▋   | 68/101 [07:45<03:29,  6.36s/it]
# Processed 3400 items
#  68%|██████▊   | 69/101 [07:51<03:23,  6.36s/it]
# Processed 3450 items
#  69%|██████▉   | 70/101 [07:57<03:13,  6.26s/it]
# Processed 3500 items
#  70%|███████   | 71/101 [08:05<03:15,  6.51s/it]
# Processed 3550 items
#  71%|███████▏  | 72/101 [08:12<03:15,  6.75s/it]
# Processed 3600 items
#  72%|███████▏  | 73/101 [08:21<03:32,  7.59s/it]
# Processed 3650 items
#  73%|███████▎  | 74/101 [08:29<03:21,  7.48s/it]
# Processed 3700 items
#  74%|███████▍  | 75/101 [08:36<03:13,  7.45s/it]
# Processed 3750 items
#  75%|███████▌  | 76/101 [08:43<03:06,  7.44s/it]
# Processed 3800 items
#  76%|███████▌  | 77/101 [08:51<02:57,  7.40s/it]
# Processed 3850 items
#  77%|███████▋  | 78/101 [08:58<02:50,  7.42s/it]
# Processed 3900 items
#  78%|███████▊  | 79/101 [09:05<02:35,  7.09s/it]
# Processed 3950 items
#  79%|███████▉  | 80/101 [09:14<02:44,  7.83s/it]
# Processed 4000 items
#  80%|████████  | 81/101 [09:20<02:23,  7.18s/it]
# Processed 4050 items
#  81%|████████  | 82/101 [09:26<02:12,  6.96s/it]
# Processed 4100 items
#  82%|████████▏ | 83/101 [09:32<02:00,  6.70s/it]
# Processed 4150 items
#  83%|████████▎ | 84/101 [09:39<01:52,  6.64s/it]
# Processed 4200 items
#  84%|████████▍ | 85/101 [09:45<01:45,  6.62s/it]
# Processed 4250 items
#  85%|████████▌ | 86/101 [09:52<01:40,  6.69s/it]
# Processed 4300 items
#  86%|████████▌ | 87/101 [09:58<01:27,  6.28s/it]
# Processed 4350 items
#  87%|████████▋ | 88/101 [10:04<01:23,  6.40s/it]
# Processed 4400 items
#  88%|████████▊ | 89/101 [10:10<01:15,  6.28s/it]
# Processed 4450 items
#  89%|████████▉ | 90/101 [10:15<01:05,  5.92s/it]
# Processed 4500 items
#  90%|█████████ | 91/101 [10:21<00:58,  5.87s/it]
# Processed 4550 items
#  91%|█████████ | 92/101 [10:29<00:57,  6.43s/it]
# Processed 4600 items
#  92%|█████████▏| 93/101 [10:35<00:50,  6.25s/it]
# Processed 4650 items
#  93%|█████████▎| 94/101 [10:41<00:43,  6.21s/it]
# Processed 4700 items
#  94%|█████████▍| 95/101 [10:46<00:36,  6.05s/it]
# Processed 4750 items
#  95%|█████████▌| 96/101 [10:52<00:29,  5.98s/it]
# Processed 4800 items
#  96%|█████████▌| 97/101 [10:58<00:23,  5.77s/it]
# Processed 4850 items
#  97%|█████████▋| 98/101 [11:03<00:17,  5.79s/it]
# Processed 4900 items
#  98%|█████████▊| 99/101 [11:09<00:11,  5.76s/it]
# Processed 4950 items
#  99%|█████████▉| 100/101 [11:16<00:06,  6.01s/it]
# Processed 5000 items
# 100%|██████████| 101/101 [11:16<00:00,  6.70s/it]
# Processed 5002 items
# Hazard_Category_LLM
# Chemical (pesticides, metals)    9851
# Microbiological                  6893
# Mycotoxins                       3363
# Others                           2454
# Allergen                         1300
# Novel food                       1115
# Physical contaminants            1109
# Migration from packaging          984
# Fraud/adulteration                328
# Name: count, dtype: int64

# %%
rasff['Hazard_Category_LLM'].value_counts()
# Out:
# Hazard_Category_LLM
# Chemical (pesticides, metals)    9851
# Microbiological                  6893
# Mycotoxins                       3363
# Others                           2454
# Allergen                         1300
# Novel food                       1115
# Physical contaminants            1109
# Migration from packaging          984
# Fraud/adulteration                328
# Name: count, dtype: int64

# %%
top_hazards = rasff['Hazard_Category_LLM'].value_counts()
plt.figure(figsize=(12,6))
sns.barplot(x=top_hazards.values, y=top_hazards.index, palette='Spectral')
plt.title("Top 10 Reported Hazards in RASFF")
plt.xlabel("Number of Notifications")
plt.ylabel("Hazard")
plt.show()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_17596\1670419620.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_hazards.values, y=top_hazards.index, palette='Spectral')

# %%
rasff.to_csv("rasff_clean4.csv", index=False)

# %% [markdown]
# - Others 4526--> 2454
# - Novel food ---> 1115
# - Fraud : still has novel food cases
# many of others cases has unauthorized cases
