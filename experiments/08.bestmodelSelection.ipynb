# %%
import pandas as pd

df=pd.read_csv(r"/content/df_keyword.csv")

# %%
# %pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.9.0

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report
from category_encoders import TargetEncoder
from sentence_transformers import SentenceTransformer

from xgboost import XGBClassifier

# =====================================================
# 1. Recode target (same as before)
# =====================================================
def recode_risk(risk):
    if risk in ['no risk', 'not serious', 'potential risk', 'undecided', 'potentially serious']:
        return 0
    elif risk == 'serious':
        return 1
    else:
        return -1

df["risk_decision_2class"] = df["risk_decision"].apply(recode_risk)
df = df[df["risk_decision_2class"] != -1]

TARGET = "risk_decision_2class"

# =====================================================
# 2. Define feature groups
# =====================================================
embedding_cols = ["subject"]
onehot_cols = ["classification", "Hazard_Type"]

target_encoding_cols = ["notifying_country", "origin", "simplified_hazard"]

# Fill missing
for col in embedding_cols + onehot_cols + target_encoding_cols:
    df[col] = df[col].fillna("missing")


# =====================================================
# 2a. Group rare categories to reduce overfitting
# =====================================================
# Category: group rare categories (<50 samples)
threshold_category = 50
counts = df['category'].value_counts()
rare_categories = counts[counts < threshold_category].index
df['category_grouped'] = df['category'].replace(rare_categories, 'other')

# Target encoding columns: group rare categories
for col in target_encoding_cols:
    counts = df[col].value_counts()
    rare = counts[counts < 50].index
    df[col] = df[col].replace(rare, 'other')


# =====================================================
# 3. SentenceTransformer Embedding
# =====================================================
from sentence_transformers import SentenceTransformer

model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(model_name)

def embed_column(series):
    return embedder.encode(series.tolist(), convert_to_numpy=True)

print("Generating embeddings for:", embedding_cols)

embedding_features = []
for col in embedding_cols:
    emb = embed_column(df[col])
    # Rename embedding columns (e.g., subject_emb_0, subject_emb_1...)
    emb_df = pd.DataFrame(
        emb,
        columns=[f"{col}_emb_{i}" for i in range(emb.shape[1])]
    )
    embedding_features.append(emb_df)

embedding_df = pd.concat(embedding_features, axis=1)

#PCA Reduce feature dimensionality
#subject embeddings are 384-dim → could apply PCA to reduce to 50–100 dims without losing much info
from sklearn.decomposition import PCA

pca = PCA(n_components=100, random_state=42)
subject_emb_pca = pca.fit_transform(embedding_df.filter(like='subject_emb'))
embedding_df_pca = pd.DataFrame(subject_emb_pca, columns=[f'subject_emb_{i}' for i in range(100)])


# =====================================================
# 4. Smoothed Target Encoding
# =====================================================
from category_encoders import TargetEncoder

print("Applying Smoothed Target Encoding:", target_encoding_cols)

te = TargetEncoder(cols=target_encoding_cols, smoothing=10)
target_encoded_df = te.fit_transform(df[target_encoding_cols], df[TARGET])


# =====================================================
# 5. One-Hot Encoding
# =====================================================
print("Applying One-Hot Encoding:", onehot_cols + ['category_grouped'])

ohe = OneHotEncoder(drop="first", sparse_output=False)
ohe_array = ohe.fit_transform(df[onehot_cols + ['category_grouped']])

ohe_df = pd.DataFrame(
    ohe_array,
    columns=ohe.get_feature_names_out(onehot_cols + ['category_grouped'])
)


# =====================================================
# 6. Combine all engineered features
# =====================================================
X = pd.concat([embedding_df, target_encoded_df, ohe_df], axis=1)
y = df[TARGET]

print("Final feature matrix shape:", X.shape)


# =====================================================
# 7. Sanitize feature names for XGBoost compatibility
# =====================================================
X.columns = (
    X.columns
      .str.replace(r'[\[\]\{\}\:\"\'\,]', '_', regex=True)
      .str.replace(r'[^A-Za-z0-9_]+', '_', regex=True)
)
# Out:
# Generating embeddings for: ['subject']
# Applying Smoothed Target Encoding: ['notifying_country', 'origin', 'simplified_hazard']
# Applying One-Hot Encoding: ['classification', 'Hazard_Type', 'category_grouped']
# Final feature matrix shape: (27397, 427)

# %%
# =====================================================
# 7. Train/Test Split
# =====================================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# ============================================
# Recreate model with best parameters
# ============================================
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    device='cuda',
    predictor='gpu_predictor',
    random_state=42,
    n_estimators=500,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    min_child_weight=1,
    reg_alpha=1,    # L1 regularization
    reg_lambda=2    # L2 regularization
)

# ============================================
# Fit on training data
# ============================================
xgb_model.fit(X_train, y_train)

# ============================================
# Predict on training data (optional, for quick evaluation)
# ============================================
y_train_pred = xgb_model.predict(X_train)
print("=== Training Data Performance ===")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))

# ============================================
# Predict on test data
# ============================================
y_test_pred = xgb_model.predict(X_test)
print("=== Test Data Performance ===")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:16:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Training Data Performance ===
# Accuracy: 0.9332012306408719
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93      8848
#            1       0.92      0.96      0.94     10329
#
#     accuracy                           0.93     19177
#    macro avg       0.94      0.93      0.93     19177
# weighted avg       0.93      0.93      0.93     19177
#
# === Test Data Performance ===
# Accuracy: 0.8736009732360097
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      3793
#            1       0.86      0.91      0.89      4427
#
#     accuracy                           0.87      8220
#    macro avg       0.88      0.87      0.87      8220
# weighted avg       0.87      0.87      0.87      8220

# %%
import joblib
import json

# ===============================
# 1. Save Model
# ===============================
joblib.dump(xgb_model, "xgb_model.pkl")

# ===============================
# 2. Save Preprocessing Objects
# ===============================
joblib.dump(te, "target_encoder.pkl")
joblib.dump(ohe, "onehot_encoder.pkl")
joblib.dump(pca, "pca_subject.pkl")

# ===============================
# 3. Save Column Info (JSON)
# ===============================
preprocess_info = {
    "embedding_cols": embedding_cols,
    "target_encoding_cols": target_encoding_cols,
    "onehot_cols": onehot_cols + ["category_grouped"],
    "pca_output_dim": 100,
    "ohe_feature_names": list(ohe.get_feature_names_out(onehot_cols + ["category_grouped"])),
    "final_feature_names": list(X.columns),
    "sentence_model_name": model_name
}

with open("preprocessing_info.json", "w") as f:
    json.dump(preprocess_info, f, indent=4)

print("All model & preprocessing files saved successfully!")
# Out:
# All model & preprocessing files saved successfully!

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# ============================================
# Recreate model with best parameters
# ============================================
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    device='cuda',
    predictor='gpu_predictor',
    random_state=42,
    n_estimators=1000,          # best parameter
    max_depth=8,                # best parameter
    learning_rate=0.01,         # best parameter
    subsample=0.8,              # best parameter
    colsample_bytree=0.6,       # best parameter
    gamma=0,                    # best parameter
    min_child_weight=5,         # best parameter
    reg_alpha=0.05,             # best parameter
    reg_lambda=2.0              # best parameter
)

# ============================================
# Fit on training data with early stopping
# ============================================
xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],  # monitor performance on test set
)

# ============================================
# Predict on training data
# ============================================
y_train_pred = xgb_model.predict(X_train)
print("=== Training Data Performance ===")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))

# ============================================
# Predict on test data
# ============================================
y_test_pred = xgb_model.predict(X_test)
print("=== Test Data Performance ===")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [09:43:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-logloss:0.68706
# [1]	validation_0-logloss:0.68364
# [2]	validation_0-logloss:0.67894
# [3]	validation_0-logloss:0.67555
# [4]	validation_0-logloss:0.67251
# [5]	validation_0-logloss:0.66784
# [6]	validation_0-logloss:0.66526
# [7]	validation_0-logloss:0.66080
# [8]	validation_0-logloss:0.65578
# [9]	validation_0-logloss:0.65275
# [10]	validation_0-logloss:0.64875
# [11]	validation_0-logloss:0.64438
# [12]	validation_0-logloss:0.64075
# [13]	validation_0-logloss:0.63672
# [14]	validation_0-logloss:0.63396
# [15]	validation_0-logloss:0.63099
# [16]	validation_0-logloss:0.62659
# [17]	validation_0-logloss:0.62218
# [18]	validation_0-logloss:0.61864
# [19]	validation_0-logloss:0.61660
# [20]	validation_0-logloss:0.61480
# [21]	validation_0-logloss:0.61296
# [22]	validation_0-logloss:0.60966
# [23]	validation_0-logloss:0.60598
# [24]	validation_0-logloss:0.60271
# [25]	validation_0-logloss:0.59952
# [26]	validation_0-logloss:0.59761
# [27]	validation_0-logloss:0.59541
# [28]	validation_0-logloss:0.59316
# [29]	validation_0-logloss:0.58935
# [30]	validation_0-logloss:0.58704
# [31]	validation_0-logloss:0.58367
# [32]	validation_0-logloss:0.58035
# [33]	validation_0-logloss:0.57828
# [34]	validation_0-logloss:0.57461
# [35]	validation_0-logloss:0.57137
# [36]	validation_0-logloss:0.56828
# [37]	validation_0-logloss:0.56485
# [38]	validation_0-logloss:0.56340
# [39]	validation_0-logloss:0.56059
# [40]	validation_0-logloss:0.55771
# [41]	validation_0-logloss:0.55491
# [42]	validation_0-logloss:0.55318
# [43]	validation_0-logloss:0.55033
# [44]	validation_0-logloss:0.54801
# [45]	validation_0-logloss:0.54550
# [46]	validation_0-logloss:0.54421
# [47]	validation_0-logloss:0.54290
# [48]	validation_0-logloss:0.54007
# [49]	validation_0-logloss:0.53709
# [50]	validation_0-logloss:0.53555
# [51]	validation_0-logloss:0.53298
# [52]	validation_0-logloss:0.53139
# [53]	validation_0-logloss:0.52889
# [54]	validation_0-logloss:0.52780
# [55]	validation_0-logloss:0.52534
# [56]	validation_0-logloss:0.52313
# [57]	validation_0-logloss:0.52151
# [58]	validation_0-logloss:0.51936
# [59]	validation_0-logloss:0.51663
# [60]	validation_0-logloss:0.51396
# [61]	validation_0-logloss:0.51152
# [62]	validation_0-logloss:0.50916
# [63]	validation_0-logloss:0.50695
# [64]	validation_0-logloss:0.50509
# [65]	validation_0-logloss:0.50305
# [66]	validation_0-logloss:0.50112
# [67]	validation_0-logloss:0.50013
# [68]	validation_0-logloss:0.49817
# [69]	validation_0-logloss:0.49717
# [70]	validation_0-logloss:0.49585
# [71]	validation_0-logloss:0.49450
# [72]	validation_0-logloss:0.49350
# [73]	validation_0-logloss:0.49219
# [74]	validation_0-logloss:0.49032
# [75]	validation_0-logloss:0.48846
# [76]	validation_0-logloss:0.48666
# [77]	validation_0-logloss:0.48501
# [78]	validation_0-logloss:0.48335
# [79]	validation_0-logloss:0.48242
# [80]	validation_0-logloss:0.48108
# [81]	validation_0-logloss:0.47999
# [82]	validation_0-logloss:0.47806
# [83]	validation_0-logloss:0.47680
# [84]	validation_0-logloss:0.47590
# [85]	validation_0-logloss:0.47505
# [86]	validation_0-logloss:0.47391
# [87]	validation_0-logloss:0.47221
# [88]	validation_0-logloss:0.47024
# [89]	validation_0-logloss:0.46942
# [90]	validation_0-logloss:0.46791
# [91]	validation_0-logloss:0.46714
# [92]	validation_0-logloss:0.46615
# [93]	validation_0-logloss:0.46518
# [94]	validation_0-logloss:0.46368
# [95]	validation_0-logloss:0.46201
# [96]	validation_0-logloss:0.46122
# [97]	validation_0-logloss:0.45961
# [98]	validation_0-logloss:0.45776
# [99]	validation_0-logloss:0.45595
# [100]	validation_0-logloss:0.45445
# [101]	validation_0-logloss:0.45311
# [102]	validation_0-logloss:0.45162
# [103]	validation_0-logloss:0.45030
# [104]	validation_0-logloss:0.44900
# [105]	validation_0-logloss:0.44755
# [106]	validation_0-logloss:0.44638
# [107]	validation_0-logloss:0.44502
# [108]	validation_0-logloss:0.44438
# [109]	validation_0-logloss:0.44308
# [110]	validation_0-logloss:0.44141
# [111]	validation_0-logloss:0.44081
# [112]	validation_0-logloss:0.43991
# [113]	validation_0-logloss:0.43835
# [114]	validation_0-logloss:0.43702
# [115]	validation_0-logloss:0.43643
# [116]	validation_0-logloss:0.43516
# [117]	validation_0-logloss:0.43445
# [118]	validation_0-logloss:0.43320
# [119]	validation_0-logloss:0.43177
# [120]	validation_0-logloss:0.43050
# [121]	validation_0-logloss:0.42944
# [122]	validation_0-logloss:0.42886
# [123]	validation_0-logloss:0.42771
# [124]	validation_0-logloss:0.42669
# [125]	validation_0-logloss:0.42550
# [126]	validation_0-logloss:0.42430
# [127]	validation_0-logloss:0.42296
# [128]	validation_0-logloss:0.42184
# [129]	validation_0-logloss:0.42113
# [130]	validation_0-logloss:0.42006
# [131]	validation_0-logloss:0.41868
# [132]	validation_0-logloss:0.41762
# [133]	validation_0-logloss:0.41630
# [134]	validation_0-logloss:0.41586
# [135]	validation_0-logloss:0.41459
# [136]	validation_0-logloss:0.41341
# [137]	validation_0-logloss:0.41221
# [138]	validation_0-logloss:0.41152
# [139]	validation_0-logloss:0.41030
# [140]	validation_0-logloss:0.40936
# [141]	validation_0-logloss:0.40815
# [142]	validation_0-logloss:0.40754
# [143]	validation_0-logloss:0.40671
# [144]	validation_0-logloss:0.40620
# [145]	validation_0-logloss:0.40508
# [146]	validation_0-logloss:0.40443
# [147]	validation_0-logloss:0.40350
# [148]	validation_0-logloss:0.40260
# [149]	validation_0-logloss:0.40175
# [150]	validation_0-logloss:0.40089
# [151]	validation_0-logloss:0.40016
# [152]	validation_0-logloss:0.39952
# [153]	validation_0-logloss:0.39894
# [154]	validation_0-logloss:0.39815
# [155]	validation_0-logloss:0.39708
# [156]	validation_0-logloss:0.39648
# [157]	validation_0-logloss:0.39599
# [158]	validation_0-logloss:0.39548
# [159]	validation_0-logloss:0.39469
# [160]	validation_0-logloss:0.39417
# [161]	validation_0-logloss:0.39346
# [162]	validation_0-logloss:0.39260
# [163]	validation_0-logloss:0.39157
# [164]	validation_0-logloss:0.39062
# [165]	validation_0-logloss:0.39016
# [166]	validation_0-logloss:0.38939
# [167]	validation_0-logloss:0.38889
# [168]	validation_0-logloss:0.38816
# [169]	validation_0-logloss:0.38739
# [170]	validation_0-logloss:0.38689
# [171]	validation_0-logloss:0.38642
# [172]	validation_0-logloss:0.38605
# [173]	validation_0-logloss:0.38516
# [174]	validation_0-logloss:0.38450
# [175]	validation_0-logloss:0.38407
# [176]	validation_0-logloss:0.38319
# [177]	validation_0-logloss:0.38282
# [178]	validation_0-logloss:0.38243
# [179]	validation_0-logloss:0.38202
# [180]	validation_0-logloss:0.38118
# [181]	validation_0-logloss:0.38060
# [182]	validation_0-logloss:0.37998
# [183]	validation_0-logloss:0.37960
# [184]	validation_0-logloss:0.37913
# [185]	validation_0-logloss:0.37844
# [186]	validation_0-logloss:0.37777
# [187]	validation_0-logloss:0.37736
# [188]	validation_0-logloss:0.37656
# [189]	validation_0-logloss:0.37625
# [190]	validation_0-logloss:0.37546
# [191]	validation_0-logloss:0.37487
# [192]	validation_0-logloss:0.37427
# [193]	validation_0-logloss:0.37398
# [194]	validation_0-logloss:0.37317
# [195]	validation_0-logloss:0.37254
# [196]	validation_0-logloss:0.37200
# [197]	validation_0-logloss:0.37168
# [198]	validation_0-logloss:0.37142
# [199]	validation_0-logloss:0.37085
# [200]	validation_0-logloss:0.37029
# [201]	validation_0-logloss:0.36996
# [202]	validation_0-logloss:0.36957
# [203]	validation_0-logloss:0.36908
# [204]	validation_0-logloss:0.36875
# [205]	validation_0-logloss:0.36818
# [206]	validation_0-logloss:0.36792
# [207]	validation_0-logloss:0.36739
# [208]	validation_0-logloss:0.36716
# [209]	validation_0-logloss:0.36649
# [210]	validation_0-logloss:0.36612
# [211]	validation_0-logloss:0.36564
# [212]	validation_0-logloss:0.36526
# [213]	validation_0-logloss:0.36477
# [214]	validation_0-logloss:0.36421
# [215]	validation_0-logloss:0.36380
# [216]	validation_0-logloss:0.36315
# [217]	validation_0-logloss:0.36264
# [218]	validation_0-logloss:0.36242
# [219]	validation_0-logloss:0.36200
# [220]	validation_0-logloss:0.36150
# [221]	validation_0-logloss:0.36101
# [222]	validation_0-logloss:0.36036
# [223]	validation_0-logloss:0.35977
# [224]	validation_0-logloss:0.35929
# [225]	validation_0-logloss:0.35881
# [226]	validation_0-logloss:0.35855
# [227]	validation_0-logloss:0.35814
# [228]	validation_0-logloss:0.35783
# [229]	validation_0-logloss:0.35726
# [230]	validation_0-logloss:0.35705
# [231]	validation_0-logloss:0.35661
# [232]	validation_0-logloss:0.35631
# [233]	validation_0-logloss:0.35574
# [234]	validation_0-logloss:0.35531
# [235]	validation_0-logloss:0.35474
# [236]	validation_0-logloss:0.35456
# [237]	validation_0-logloss:0.35411
# [238]	validation_0-logloss:0.35389
# [239]	validation_0-logloss:0.35367
# [240]	validation_0-logloss:0.35328
# [241]	validation_0-logloss:0.35286
# [242]	validation_0-logloss:0.35236
# [243]	validation_0-logloss:0.35214
# [244]	validation_0-logloss:0.35165
# [245]	validation_0-logloss:0.35123
# [246]	validation_0-logloss:0.35074
# [247]	validation_0-logloss:0.35051
# [248]	validation_0-logloss:0.35034
# [249]	validation_0-logloss:0.35009
# [250]	validation_0-logloss:0.34992
# [251]	validation_0-logloss:0.34944
# [252]	validation_0-logloss:0.34910
# [253]	validation_0-logloss:0.34889
# [254]	validation_0-logloss:0.34860
# [255]	validation_0-logloss:0.34837
# [256]	validation_0-logloss:0.34804
# [257]	validation_0-logloss:0.34785
# [258]	validation_0-logloss:0.34740
# [259]	validation_0-logloss:0.34697
# [260]	validation_0-logloss:0.34684
# [261]	validation_0-logloss:0.34656
# [262]	validation_0-logloss:0.34638
# [263]	validation_0-logloss:0.34589
# [264]	validation_0-logloss:0.34574
# [265]	validation_0-logloss:0.34553
# [266]	validation_0-logloss:0.34531
# [267]	validation_0-logloss:0.34516
# [268]	validation_0-logloss:0.34492
# [269]	validation_0-logloss:0.34460
# [270]	validation_0-logloss:0.34432
# [271]	validation_0-logloss:0.34401
# [272]	validation_0-logloss:0.34371
# [273]	validation_0-logloss:0.34350
# [274]	validation_0-logloss:0.34319
# [275]	validation_0-logloss:0.34283
# [276]	validation_0-logloss:0.34269
# [277]	validation_0-logloss:0.34232
# [278]	validation_0-logloss:0.34191
# [279]	validation_0-logloss:0.34151
# [280]	validation_0-logloss:0.34121
# [281]	validation_0-logloss:0.34090
# [282]	validation_0-logloss:0.34051
# [283]	validation_0-logloss:0.34024
# [284]	validation_0-logloss:0.33997
# [285]	validation_0-logloss:0.33967
# [286]	validation_0-logloss:0.33947
# [287]	validation_0-logloss:0.33922
# [288]	validation_0-logloss:0.33899
# [289]	validation_0-logloss:0.33864
# [290]	validation_0-logloss:0.33843
# [291]	validation_0-logloss:0.33807
# [292]	validation_0-logloss:0.33780
# [293]	validation_0-logloss:0.33757
# [294]	validation_0-logloss:0.33739
# [295]	validation_0-logloss:0.33715
# [296]	validation_0-logloss:0.33701
# [297]	validation_0-logloss:0.33690
# [298]	validation_0-logloss:0.33667
# [299]	validation_0-logloss:0.33632
# [300]	validation_0-logloss:0.33595
# [301]	validation_0-logloss:0.33583
# [302]	validation_0-logloss:0.33576
# [303]	validation_0-logloss:0.33550
# [304]	validation_0-logloss:0.33536
# [305]	validation_0-logloss:0.33508
# [306]	validation_0-logloss:0.33485
# [307]	validation_0-logloss:0.33476
# [308]	validation_0-logloss:0.33457
# [309]	validation_0-logloss:0.33435
# [310]	validation_0-logloss:0.33410
# [311]	validation_0-logloss:0.33385
# [312]	validation_0-logloss:0.33364
# [313]	validation_0-logloss:0.33352
# [314]	validation_0-logloss:0.33330
# [315]	validation_0-logloss:0.33311
# [316]	validation_0-logloss:0.33295
# [317]	validation_0-logloss:0.33282
# [318]	validation_0-logloss:0.33253
# [319]	validation_0-logloss:0.33243
# [320]	validation_0-logloss:0.33208
# [321]	validation_0-logloss:0.33186
# [322]	validation_0-logloss:0.33173
# [323]	validation_0-logloss:0.33152
# [324]	validation_0-logloss:0.33136
# [325]	validation_0-logloss:0.33112
# [326]	validation_0-logloss:0.33085
# [327]	validation_0-logloss:0.33053
# [328]	validation_0-logloss:0.33025
# [329]	validation_0-logloss:0.33015
# [330]	validation_0-logloss:0.32985
# [331]	validation_0-logloss:0.32976
# [332]	validation_0-logloss:0.32948
# [333]	validation_0-logloss:0.32931
# [334]	validation_0-logloss:0.32922
# [335]	validation_0-logloss:0.32905
# [336]	validation_0-logloss:0.32888
# [337]	validation_0-logloss:0.32869
# [338]	validation_0-logloss:0.32843
# [339]	validation_0-logloss:0.32837
# [340]	validation_0-logloss:0.32827
# [341]	validation_0-logloss:0.32802
# [342]	validation_0-logloss:0.32792
# [343]	validation_0-logloss:0.32782
# [344]	validation_0-logloss:0.32765
# [345]	validation_0-logloss:0.32740
# [346]	validation_0-logloss:0.32718
# [347]	validation_0-logloss:0.32706
# [348]	validation_0-logloss:0.32683
# [349]	validation_0-logloss:0.32674
# [350]	validation_0-logloss:0.32657
# [351]	validation_0-logloss:0.32649
# [352]	validation_0-logloss:0.32635
# [353]	validation_0-logloss:0.32618
# [354]	validation_0-logloss:0.32601
# [355]	validation_0-logloss:0.32584
# [356]	validation_0-logloss:0.32579
# [357]	validation_0-logloss:0.32572
# [358]	validation_0-logloss:0.32564
# [359]	validation_0-logloss:0.32557
# [360]	validation_0-logloss:0.32535
# [361]	validation_0-logloss:0.32519
# [362]	validation_0-logloss:0.32513
# [363]	validation_0-logloss:0.32488
# [364]	validation_0-logloss:0.32475
# [365]	validation_0-logloss:0.32463
# [366]	validation_0-logloss:0.32450
# [367]	validation_0-logloss:0.32434
# [368]	validation_0-logloss:0.32409
# [369]	validation_0-logloss:0.32401
# [370]	validation_0-logloss:0.32392
# [371]	validation_0-logloss:0.32372
# [372]	validation_0-logloss:0.32349
# [373]	validation_0-logloss:0.32343
# [374]	validation_0-logloss:0.32334
# [375]	validation_0-logloss:0.32317
# [376]	validation_0-logloss:0.32306
# [377]	validation_0-logloss:0.32289
# [378]	validation_0-logloss:0.32281
# [379]	validation_0-logloss:0.32274
# [380]	validation_0-logloss:0.32253
# [381]	validation_0-logloss:0.32240
# [382]	validation_0-logloss:0.32230
# [383]	validation_0-logloss:0.32219
# [384]	validation_0-logloss:0.32201
# [385]	validation_0-logloss:0.32195
# [386]	validation_0-logloss:0.32190
# [387]	validation_0-logloss:0.32170
# [388]	validation_0-logloss:0.32154
# [389]	validation_0-logloss:0.32149
# [390]	validation_0-logloss:0.32137
# [391]	validation_0-logloss:0.32128
# [392]	validation_0-logloss:0.32118
# [393]	validation_0-logloss:0.32102
# [394]	validation_0-logloss:0.32096
# [395]	validation_0-logloss:0.32090
# [396]	validation_0-logloss:0.32085
# [397]	validation_0-logloss:0.32070
# [398]	validation_0-logloss:0.32063
# [399]	validation_0-logloss:0.32046
# [400]	validation_0-logloss:0.32041
# [401]	validation_0-logloss:0.32028
# [402]	validation_0-logloss:0.32017
# [403]	validation_0-logloss:0.31999
# [404]	validation_0-logloss:0.31990
# [405]	validation_0-logloss:0.31972
# [406]	validation_0-logloss:0.31956
# [407]	validation_0-logloss:0.31945
# [408]	validation_0-logloss:0.31938
# [409]	validation_0-logloss:0.31929
# [410]	validation_0-logloss:0.31923
# [411]	validation_0-logloss:0.31918
# [412]	validation_0-logloss:0.31909
# [413]	validation_0-logloss:0.31903
# [414]	validation_0-logloss:0.31900
# [415]	validation_0-logloss:0.31889
# [416]	validation_0-logloss:0.31880
# [417]	validation_0-logloss:0.31872
# [418]	validation_0-logloss:0.31862
# [419]	validation_0-logloss:0.31857
# [420]	validation_0-logloss:0.31850
# [421]	validation_0-logloss:0.31843
# [422]	validation_0-logloss:0.31834
# [423]	validation_0-logloss:0.31820
# [424]	validation_0-logloss:0.31811
# [425]	validation_0-logloss:0.31806
# [426]	validation_0-logloss:0.31791
# [427]	validation_0-logloss:0.31784
# [428]	validation_0-logloss:0.31772
# [429]	validation_0-logloss:0.31765
# [430]	validation_0-logloss:0.31762
# [431]	validation_0-logloss:0.31757
# [432]	validation_0-logloss:0.31743
# [433]	validation_0-logloss:0.31738
# [434]	validation_0-logloss:0.31735
# [435]	validation_0-logloss:0.31732
# [436]	validation_0-logloss:0.31718
# [437]	validation_0-logloss:0.31711
# [438]	validation_0-logloss:0.31699
# [439]	validation_0-logloss:0.31690
# [440]	validation_0-logloss:0.31675
# [441]	validation_0-logloss:0.31666
# [442]	validation_0-logloss:0.31665
# [443]	validation_0-logloss:0.31657
# [444]	validation_0-logloss:0.31650
# [445]	validation_0-logloss:0.31644
# [446]	validation_0-logloss:0.31636
# [447]	validation_0-logloss:0.31622
# [448]	validation_0-logloss:0.31612
# [449]	validation_0-logloss:0.31606
# [450]	validation_0-logloss:0.31593
# [451]	validation_0-logloss:0.31588
# [452]	validation_0-logloss:0.31577
# [453]	validation_0-logloss:0.31569
# [454]	validation_0-logloss:0.31563
# [455]	validation_0-logloss:0.31557
# [456]	validation_0-logloss:0.31553
# [457]	validation_0-logloss:0.31545
# [458]	validation_0-logloss:0.31539
# [459]	validation_0-logloss:0.31532
# [460]	validation_0-logloss:0.31524
# [461]	validation_0-logloss:0.31518
# [462]	validation_0-logloss:0.31512
# [463]	validation_0-logloss:0.31510
# [464]	validation_0-logloss:0.31503
# [465]	validation_0-logloss:0.31491
# [466]	validation_0-logloss:0.31486
# [467]	validation_0-logloss:0.31478
# [468]	validation_0-logloss:0.31472
# [469]	validation_0-logloss:0.31471
# [470]	validation_0-logloss:0.31460
# [471]	validation_0-logloss:0.31455
# [472]	validation_0-logloss:0.31451
# [473]	validation_0-logloss:0.31447
# [474]	validation_0-logloss:0.31437
# [475]	validation_0-logloss:0.31426
# [476]	validation_0-logloss:0.31422
# [477]	validation_0-logloss:0.31412
# [478]	validation_0-logloss:0.31401
# [479]	validation_0-logloss:0.31388
# [480]	validation_0-logloss:0.31382
# [481]	validation_0-logloss:0.31377
# [482]	validation_0-logloss:0.31372
# [483]	validation_0-logloss:0.31365
# [484]	validation_0-logloss:0.31363
# [485]	validation_0-logloss:0.31352
# [486]	validation_0-logloss:0.31346
# [487]	validation_0-logloss:0.31344
# [488]	validation_0-logloss:0.31337
# [489]	validation_0-logloss:0.31333
# [490]	validation_0-logloss:0.31328
# [491]	validation_0-logloss:0.31321
# [492]	validation_0-logloss:0.31316
# [493]	validation_0-logloss:0.31312
# [494]	validation_0-logloss:0.31302
# [495]	validation_0-logloss:0.31300
# [496]	validation_0-logloss:0.31291
# [497]	validation_0-logloss:0.31283
# [498]	validation_0-logloss:0.31281
# [499]	validation_0-logloss:0.31277
# [500]	validation_0-logloss:0.31273
# [501]	validation_0-logloss:0.31270
# [502]	validation_0-logloss:0.31265
# [503]	validation_0-logloss:0.31259
# [504]	validation_0-logloss:0.31250
# [505]	validation_0-logloss:0.31241
# [506]	validation_0-logloss:0.31232
# [507]	validation_0-logloss:0.31222
# [508]	validation_0-logloss:0.31215
# [509]	validation_0-logloss:0.31210
# [510]	validation_0-logloss:0.31202
# [511]	validation_0-logloss:0.31195
# [512]	validation_0-logloss:0.31188
# [513]	validation_0-logloss:0.31181
# [514]	validation_0-logloss:0.31176
# [515]	validation_0-logloss:0.31170
# [516]	validation_0-logloss:0.31164
# [517]	validation_0-logloss:0.31158
# [518]	validation_0-logloss:0.31154
# [519]	validation_0-logloss:0.31150
# [520]	validation_0-logloss:0.31147
# [521]	validation_0-logloss:0.31138
# [522]	validation_0-logloss:0.31132
# [523]	validation_0-logloss:0.31131
# [524]	validation_0-logloss:0.31126
# [525]	validation_0-logloss:0.31121
# [526]	validation_0-logloss:0.31117
# [527]	validation_0-logloss:0.31112
# [528]	validation_0-logloss:0.31107
# [529]	validation_0-logloss:0.31106
# [530]	validation_0-logloss:0.31106
# [531]	validation_0-logloss:0.31102
# [532]	validation_0-logloss:0.31098
# [533]	validation_0-logloss:0.31091
# [534]	validation_0-logloss:0.31083
# [535]	validation_0-logloss:0.31071
# [536]	validation_0-logloss:0.31064
# [537]	validation_0-logloss:0.31057
# [538]	validation_0-logloss:0.31055
# [539]	validation_0-logloss:0.31055
# [540]	validation_0-logloss:0.31051
# [541]	validation_0-logloss:0.31042
# [542]	validation_0-logloss:0.31036
# [543]	validation_0-logloss:0.31027
# [544]	validation_0-logloss:0.31022
# [545]	validation_0-logloss:0.31019
# [546]	validation_0-logloss:0.31008
# [547]	validation_0-logloss:0.31000
# [548]	validation_0-logloss:0.30998
# [549]	validation_0-logloss:0.30997
# [550]	validation_0-logloss:0.30993
# [551]	validation_0-logloss:0.30989
# [552]	validation_0-logloss:0.30983
# [553]	validation_0-logloss:0.30977
# [554]	validation_0-logloss:0.30970
# [555]	validation_0-logloss:0.30968
# [556]	validation_0-logloss:0.30964
# [557]	validation_0-logloss:0.30964
# [558]	validation_0-logloss:0.30962
# [559]	validation_0-logloss:0.30958
# [560]	validation_0-logloss:0.30953
# [561]	validation_0-logloss:0.30949
# [562]	validation_0-logloss:0.30943
# [563]	validation_0-logloss:0.30939
# [564]	validation_0-logloss:0.30934
# [565]	validation_0-logloss:0.30930
# [566]	validation_0-logloss:0.30924
# [567]	validation_0-logloss:0.30924
# [568]	validation_0-logloss:0.30923
# [569]	validation_0-logloss:0.30921
# [570]	validation_0-logloss:0.30918
# [571]	validation_0-logloss:0.30914
# [572]	validation_0-logloss:0.30908
# [573]	validation_0-logloss:0.30905
# [574]	validation_0-logloss:0.30899
# [575]	validation_0-logloss:0.30897
# [576]	validation_0-logloss:0.30893
# [577]	validation_0-logloss:0.30890
# [578]	validation_0-logloss:0.30887
# [579]	validation_0-logloss:0.30886
# [580]	validation_0-logloss:0.30887
# [581]	validation_0-logloss:0.30884
# [582]	validation_0-logloss:0.30878
# [583]	validation_0-logloss:0.30875
# [584]	validation_0-logloss:0.30874
# [585]	validation_0-logloss:0.30868
# [586]	validation_0-logloss:0.30867
# [587]	validation_0-logloss:0.30864
# [588]	validation_0-logloss:0.30858
# [589]	validation_0-logloss:0.30854
# [590]	validation_0-logloss:0.30850
# [591]	validation_0-logloss:0.30847
# [592]	validation_0-logloss:0.30847
# [593]	validation_0-logloss:0.30844
# [594]	validation_0-logloss:0.30842
# [595]	validation_0-logloss:0.30836
# [596]	validation_0-logloss:0.30834
# [597]	validation_0-logloss:0.30828
# [598]	validation_0-logloss:0.30824
# [599]	validation_0-logloss:0.30823
# [600]	validation_0-logloss:0.30816
# [601]	validation_0-logloss:0.30814
# [602]	validation_0-logloss:0.30808
# [603]	validation_0-logloss:0.30804
# [604]	validation_0-logloss:0.30802
# [605]	validation_0-logloss:0.30799
# [606]	validation_0-logloss:0.30796
# [607]	validation_0-logloss:0.30793
# [608]	validation_0-logloss:0.30791
# [609]	validation_0-logloss:0.30786
# [610]	validation_0-logloss:0.30783
# [611]	validation_0-logloss:0.30779
# [612]	validation_0-logloss:0.30777
# [613]	validation_0-logloss:0.30770
# [614]	validation_0-logloss:0.30767
# [615]	validation_0-logloss:0.30766
# [616]	validation_0-logloss:0.30762
# [617]	validation_0-logloss:0.30759
# [618]	validation_0-logloss:0.30757
# [619]	validation_0-logloss:0.30754
# [620]	validation_0-logloss:0.30747
# [621]	validation_0-logloss:0.30745
# [622]	validation_0-logloss:0.30743
# [623]	validation_0-logloss:0.30742
# [624]	validation_0-logloss:0.30739
# [625]	validation_0-logloss:0.30736
# [626]	validation_0-logloss:0.30734
# [627]	validation_0-logloss:0.30730
# [628]	validation_0-logloss:0.30725
# [629]	validation_0-logloss:0.30723
# [630]	validation_0-logloss:0.30721
# [631]	validation_0-logloss:0.30716
# [632]	validation_0-logloss:0.30713
# [633]	validation_0-logloss:0.30707
# [634]	validation_0-logloss:0.30706
# [635]	validation_0-logloss:0.30705
# [636]	validation_0-logloss:0.30702
# [637]	validation_0-logloss:0.30698
# [638]	validation_0-logloss:0.30696
# [639]	validation_0-logloss:0.30695
# [640]	validation_0-logloss:0.30692
# [641]	validation_0-logloss:0.30690
# [642]	validation_0-logloss:0.30690
# [643]	validation_0-logloss:0.30685
# [644]	validation_0-logloss:0.30681
# [645]	validation_0-logloss:0.30681
# [646]	validation_0-logloss:0.30677
# [647]	validation_0-logloss:0.30677
# [648]	validation_0-logloss:0.30674
# [649]	validation_0-logloss:0.30672
# [650]	validation_0-logloss:0.30672
# [651]	validation_0-logloss:0.30672
# [652]	validation_0-logloss:0.30669
# [653]	validation_0-logloss:0.30667
# [654]	validation_0-logloss:0.30662
# [655]	validation_0-logloss:0.30660
# [656]	validation_0-logloss:0.30657
# [657]	validation_0-logloss:0.30656
# [658]	validation_0-logloss:0.30655
# [659]	validation_0-logloss:0.30652
# [660]	validation_0-logloss:0.30648
# [661]	validation_0-logloss:0.30647
# [662]	validation_0-logloss:0.30646
# [663]	validation_0-logloss:0.30646
# [664]	validation_0-logloss:0.30644
# [665]	validation_0-logloss:0.30640
# [666]	validation_0-logloss:0.30638
# [667]	validation_0-logloss:0.30636
# [668]	validation_0-logloss:0.30631
# [669]	validation_0-logloss:0.30631
# [670]	validation_0-logloss:0.30630
# [671]	validation_0-logloss:0.30629
# [672]	validation_0-logloss:0.30626
# [673]	validation_0-logloss:0.30624
# [674]	validation_0-logloss:0.30623
# [675]	validation_0-logloss:0.30623
# [676]	validation_0-logloss:0.30618
# [677]	validation_0-logloss:0.30618
# [678]	validation_0-logloss:0.30616
# [679]	validation_0-logloss:0.30618
# [680]	validation_0-logloss:0.30617
# [681]	validation_0-logloss:0.30618
# [682]	validation_0-logloss:0.30617
# [683]	validation_0-logloss:0.30613
# [684]	validation_0-logloss:0.30611
# [685]	validation_0-logloss:0.30606
# [686]	validation_0-logloss:0.30605
# [687]	validation_0-logloss:0.30603
# [688]	validation_0-logloss:0.30603
# [689]	validation_0-logloss:0.30598
# [690]	validation_0-logloss:0.30595
# [691]	validation_0-logloss:0.30595
# [692]	validation_0-logloss:0.30592
# [693]	validation_0-logloss:0.30590
# [694]	validation_0-logloss:0.30587
# [695]	validation_0-logloss:0.30586
# [696]	validation_0-logloss:0.30586
# [697]	validation_0-logloss:0.30582
# [698]	validation_0-logloss:0.30581
# [699]	validation_0-logloss:0.30581
# [700]	validation_0-logloss:0.30583
# [701]	validation_0-logloss:0.30580
# [702]	validation_0-logloss:0.30580
# [703]	validation_0-logloss:0.30575
# [704]	validation_0-logloss:0.30575
# [705]	validation_0-logloss:0.30573
# [706]	validation_0-logloss:0.30572
# [707]	validation_0-logloss:0.30572
# [708]	validation_0-logloss:0.30570
# [709]	validation_0-logloss:0.30569
# [710]	validation_0-logloss:0.30564
# [711]	validation_0-logloss:0.30562
# [712]	validation_0-logloss:0.30559
# [713]	validation_0-logloss:0.30559
# [714]	validation_0-logloss:0.30558
# [715]	validation_0-logloss:0.30555
# [716]	validation_0-logloss:0.30553
# [717]	validation_0-logloss:0.30553
# [718]	validation_0-logloss:0.30551
# [719]	validation_0-logloss:0.30549
# [720]	validation_0-logloss:0.30548
# [721]	validation_0-logloss:0.30545
# [722]	validation_0-logloss:0.30542
# [723]	validation_0-logloss:0.30538
# [724]	validation_0-logloss:0.30537
# [725]	validation_0-logloss:0.30534
# [726]	validation_0-logloss:0.30533
# [727]	validation_0-logloss:0.30529
# [728]	validation_0-logloss:0.30531
# [729]	validation_0-logloss:0.30530
# [730]	validation_0-logloss:0.30528
# [731]	validation_0-logloss:0.30526
# [732]	validation_0-logloss:0.30522
# [733]	validation_0-logloss:0.30521
# [734]	validation_0-logloss:0.30519
# [735]	validation_0-logloss:0.30518
# [736]	validation_0-logloss:0.30517
# [737]	validation_0-logloss:0.30516
# [738]	validation_0-logloss:0.30516
# [739]	validation_0-logloss:0.30515
# [740]	validation_0-logloss:0.30510
# [741]	validation_0-logloss:0.30508
# [742]	validation_0-logloss:0.30507
# [743]	validation_0-logloss:0.30505
# [744]	validation_0-logloss:0.30502
# [745]	validation_0-logloss:0.30500
# [746]	validation_0-logloss:0.30498
# [747]	validation_0-logloss:0.30498
# [748]	validation_0-logloss:0.30496
# [749]	validation_0-logloss:0.30496
# [750]	validation_0-logloss:0.30495
# [751]	validation_0-logloss:0.30493
# [752]	validation_0-logloss:0.30491
# [753]	validation_0-logloss:0.30489
# [754]	validation_0-logloss:0.30487
# [755]	validation_0-logloss:0.30487
# [756]	validation_0-logloss:0.30487
# [757]	validation_0-logloss:0.30485
# [758]	validation_0-logloss:0.30486
# [759]	validation_0-logloss:0.30485
# [760]	validation_0-logloss:0.30483
# [761]	validation_0-logloss:0.30482
# [762]	validation_0-logloss:0.30481
# [763]	validation_0-logloss:0.30481
# [764]	validation_0-logloss:0.30478
# [765]	validation_0-logloss:0.30477
# [766]	validation_0-logloss:0.30475
# [767]	validation_0-logloss:0.30474
# [768]	validation_0-logloss:0.30471
# [769]	validation_0-logloss:0.30470
# [770]	validation_0-logloss:0.30468
# [771]	validation_0-logloss:0.30466
# [772]	validation_0-logloss:0.30465
# [773]	validation_0-logloss:0.30462
# [774]	validation_0-logloss:0.30460
# [775]	validation_0-logloss:0.30457
# [776]	validation_0-logloss:0.30456
# [777]	validation_0-logloss:0.30453
# [778]	validation_0-logloss:0.30452
# [779]	validation_0-logloss:0.30452
# [780]	validation_0-logloss:0.30450
# [781]	validation_0-logloss:0.30446
# [782]	validation_0-logloss:0.30447
# [783]	validation_0-logloss:0.30445
# [784]	validation_0-logloss:0.30443
# [785]	validation_0-logloss:0.30440
# [786]	validation_0-logloss:0.30440
# [787]	validation_0-logloss:0.30437
# [788]	validation_0-logloss:0.30434
# [789]	validation_0-logloss:0.30434
# [790]	validation_0-logloss:0.30432
# [791]	validation_0-logloss:0.30429
# [792]	validation_0-logloss:0.30430
# [793]	validation_0-logloss:0.30430
# [794]	validation_0-logloss:0.30429
# [795]	validation_0-logloss:0.30425
# [796]	validation_0-logloss:0.30422
# [797]	validation_0-logloss:0.30421
# [798]	validation_0-logloss:0.30421
# [799]	validation_0-logloss:0.30421
# [800]	validation_0-logloss:0.30423
# [801]	validation_0-logloss:0.30424
# [802]	validation_0-logloss:0.30423
# [803]	validation_0-logloss:0.30422
# [804]	validation_0-logloss:0.30418
# [805]	validation_0-logloss:0.30416
# [806]	validation_0-logloss:0.30413
# [807]	validation_0-logloss:0.30413
# [808]	validation_0-logloss:0.30413
# [809]	validation_0-logloss:0.30413
# [810]	validation_0-logloss:0.30411
# [811]	validation_0-logloss:0.30409
# [812]	validation_0-logloss:0.30405
# [813]	validation_0-logloss:0.30404
# [814]	validation_0-logloss:0.30404
# [815]	validation_0-logloss:0.30401
# [816]	validation_0-logloss:0.30401
# [817]	validation_0-logloss:0.30402
# [818]	validation_0-logloss:0.30403
# [819]	validation_0-logloss:0.30404
# [820]	validation_0-logloss:0.30398
# [821]	validation_0-logloss:0.30396
# [822]	validation_0-logloss:0.30396
# [823]	validation_0-logloss:0.30393
# [824]	validation_0-logloss:0.30394
# [825]	validation_0-logloss:0.30393
# [826]	validation_0-logloss:0.30388
# [827]	validation_0-logloss:0.30385
# [828]	validation_0-logloss:0.30383
# [829]	validation_0-logloss:0.30385
# [830]	validation_0-logloss:0.30383
# [831]	validation_0-logloss:0.30382
# [832]	validation_0-logloss:0.30381
# [833]	validation_0-logloss:0.30380
# [834]	validation_0-logloss:0.30380
# [835]	validation_0-logloss:0.30377
# [836]	validation_0-logloss:0.30371
# [837]	validation_0-logloss:0.30372
# [838]	validation_0-logloss:0.30372
# [839]	validation_0-logloss:0.30372
# [840]	validation_0-logloss:0.30372
# [841]	validation_0-logloss:0.30374
# [842]	validation_0-logloss:0.30371
# [843]	validation_0-logloss:0.30370
# [844]	validation_0-logloss:0.30369
# [845]	validation_0-logloss:0.30366
# [846]	validation_0-logloss:0.30366
# [847]	validation_0-logloss:0.30366
# [848]	validation_0-logloss:0.30367
# [849]	validation_0-logloss:0.30367
# [850]	validation_0-logloss:0.30368
# [851]	validation_0-logloss:0.30367
# [852]	validation_0-logloss:0.30366
# [853]	validation_0-logloss:0.30365
# [854]	validation_0-logloss:0.30362
# [855]	validation_0-logloss:0.30361
# [856]	validation_0-logloss:0.30362
# [857]	validation_0-logloss:0.30361
# [858]	validation_0-logloss:0.30360
# [859]	validation_0-logloss:0.30359
# [860]	validation_0-logloss:0.30356
# [861]	validation_0-logloss:0.30353
# [862]	validation_0-logloss:0.30352
# [863]	validation_0-logloss:0.30349
# [864]	validation_0-logloss:0.30346
# [865]	validation_0-logloss:0.30348
# [866]	validation_0-logloss:0.30349
# [867]	validation_0-logloss:0.30347
# [868]	validation_0-logloss:0.30343
# [869]	validation_0-logloss:0.30345
# [870]	validation_0-logloss:0.30346
# [871]	validation_0-logloss:0.30345
# [872]	validation_0-logloss:0.30344
# [873]	validation_0-logloss:0.30342
# [874]	validation_0-logloss:0.30344
# [875]	validation_0-logloss:0.30344
# [876]	validation_0-logloss:0.30342
# [877]	validation_0-logloss:0.30340
# [878]	validation_0-logloss:0.30341
# [879]	validation_0-logloss:0.30341
# [880]	validation_0-logloss:0.30339
# [881]	validation_0-logloss:0.30338
# [882]	validation_0-logloss:0.30337
# [883]	validation_0-logloss:0.30340
# [884]	validation_0-logloss:0.30343
# [885]	validation_0-logloss:0.30341
# [886]	validation_0-logloss:0.30340
# [887]	validation_0-logloss:0.30341
# [888]	validation_0-logloss:0.30339
# [889]	validation_0-logloss:0.30337
# [890]	validation_0-logloss:0.30335
# [891]	validation_0-logloss:0.30335
# [892]	validation_0-logloss:0.30336
# [893]	validation_0-logloss:0.30335
# [894]	validation_0-logloss:0.30335
# [895]	validation_0-logloss:0.30333
# [896]	validation_0-logloss:0.30331
# [897]	validation_0-logloss:0.30330
# [898]	validation_0-logloss:0.30330
# [899]	validation_0-logloss:0.30329
# [900]	validation_0-logloss:0.30329
# [901]	validation_0-logloss:0.30329
# [902]	validation_0-logloss:0.30328
# [903]	validation_0-logloss:0.30328
# [904]	validation_0-logloss:0.30327
# [905]	validation_0-logloss:0.30326
# [906]	validation_0-logloss:0.30327
# [907]	validation_0-logloss:0.30328
# [908]	validation_0-logloss:0.30326
# [909]	validation_0-logloss:0.30324
# [910]	validation_0-logloss:0.30322
# [911]	validation_0-logloss:0.30323
# [912]	validation_0-logloss:0.30322
# [913]	validation_0-logloss:0.30324
# [914]	validation_0-logloss:0.30326
# [915]	validation_0-logloss:0.30324
# [916]	validation_0-logloss:0.30321
# [917]	validation_0-logloss:0.30320
# [918]	validation_0-logloss:0.30317
# [919]	validation_0-logloss:0.30315
# [920]	validation_0-logloss:0.30315
# [921]	validation_0-logloss:0.30316
# [922]	validation_0-logloss:0.30315
# [923]	validation_0-logloss:0.30315
# [924]	validation_0-logloss:0.30315
# [925]	validation_0-logloss:0.30313
# [926]	validation_0-logloss:0.30312
# [927]	validation_0-logloss:0.30312
# [928]	validation_0-logloss:0.30314
# [929]	validation_0-logloss:0.30312
# [930]	validation_0-logloss:0.30310
# [931]	validation_0-logloss:0.30309
# [932]	validation_0-logloss:0.30304
# [933]	validation_0-logloss:0.30304
# [934]	validation_0-logloss:0.30304
# [935]	validation_0-logloss:0.30299
# [936]	validation_0-logloss:0.30298
# [937]	validation_0-logloss:0.30297
# [938]	validation_0-logloss:0.30294
# [939]	validation_0-logloss:0.30295
# [940]	validation_0-logloss:0.30296
# [941]	validation_0-logloss:0.30295
# [942]	validation_0-logloss:0.30293
# [943]	validation_0-logloss:0.30291
# [944]	validation_0-logloss:0.30291
# [945]	validation_0-logloss:0.30290
# [946]	validation_0-logloss:0.30288
# [947]	validation_0-logloss:0.30286
# [948]	validation_0-logloss:0.30285
# [949]	validation_0-logloss:0.30285
# [950]	validation_0-logloss:0.30286
# [951]	validation_0-logloss:0.30286
# [952]	validation_0-logloss:0.30285
# [953]	validation_0-logloss:0.30285
# [954]	validation_0-logloss:0.30284
# [955]	validation_0-logloss:0.30281
# [956]	validation_0-logloss:0.30282
# [957]	validation_0-logloss:0.30285
# [958]	validation_0-logloss:0.30284
# [959]	validation_0-logloss:0.30283
# [960]	validation_0-logloss:0.30282
# [961]	validation_0-logloss:0.30277
# [962]	validation_0-logloss:0.30280
# [963]	validation_0-logloss:0.30278
# [964]	validation_0-logloss:0.30278
# [965]	validation_0-logloss:0.30276
# [966]	validation_0-logloss:0.30275
# [967]	validation_0-logloss:0.30272
# [968]	validation_0-logloss:0.30270
# [969]	validation_0-logloss:0.30268
# [970]	validation_0-logloss:0.30263
# [971]	validation_0-logloss:0.30261
# [972]	validation_0-logloss:0.30260
# [973]	validation_0-logloss:0.30259
# [974]	validation_0-logloss:0.30258
# [975]	validation_0-logloss:0.30256
# [976]	validation_0-logloss:0.30256
# [977]	validation_0-logloss:0.30257
# [978]	validation_0-logloss:0.30258
# [979]	validation_0-logloss:0.30257
# [980]	validation_0-logloss:0.30257
# [981]	validation_0-logloss:0.30258
# [982]	validation_0-logloss:0.30260
# [983]	validation_0-logloss:0.30261
# [984]	validation_0-logloss:0.30262
# [985]	validation_0-logloss:0.30260
# [986]	validation_0-logloss:0.30260
# [987]	validation_0-logloss:0.30258
# [988]	validation_0-logloss:0.30260
# [989]	validation_0-logloss:0.30258
# [990]	validation_0-logloss:0.30260
# [991]	validation_0-logloss:0.30259
# [992]	validation_0-logloss:0.30260
# [993]	validation_0-logloss:0.30261
# [994]	validation_0-logloss:0.30259
# [995]	validation_0-logloss:0.30256
# [996]	validation_0-logloss:0.30255
# [997]	validation_0-logloss:0.30256
# [998]	validation_0-logloss:0.30253
# [999]	validation_0-logloss:0.30256
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:774: UserWarning: [09:43:22] WARNING: /workspace/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# === Training Data Performance ===
# Accuracy: 0.973666371173802
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      8848
#            1       0.96      0.99      0.98     10329
#
#     accuracy                           0.97     19177
#    macro avg       0.97      0.97      0.97     19177
# weighted avg       0.97      0.97      0.97     19177
#
# === Test Data Performance ===
# Accuracy: 0.8774939172749392
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86      3793
#            1       0.86      0.92      0.89      4427
#
#     accuracy                           0.88      8220
#    macro avg       0.88      0.87      0.88      8220
# weighted avg       0.88      0.88      0.88      8220

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report
from category_encoders import TargetEncoder
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA

# =====================================================
# 1. Recode target
# =====================================================
def recode_risk(risk):
    if risk in ['no risk', 'not serious', 'potential risk', 'undecided', 'potentially serious']:
        return 0
    elif risk == 'serious':
        return 1
    else:
        return -1

df["risk_decision_2class"] = df["risk_decision"].apply(recode_risk)
df = df[df["risk_decision_2class"] != -1]

TARGET = "risk_decision_2class"

# =====================================================
# 2. Define feature groups
# =====================================================
text_cols = ["subject", "category"]              # will embed
onehot_cols = ["classification", "Hazard_Type"] # low cardinality
target_encoding_cols = ["notifying_country", "origin"]  # smoothed target encoding

# Fill missing
for col in text_cols + onehot_cols + target_encoding_cols:
    df[col] = df[col].fillna("missing")

# =====================================================
# 2a. Clean text in subject (light cleaning)
# =====================================================
import re
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'\s+', ' ', text)           # remove extra spaces
    text = re.sub(r'[^a-z0-9\s]', ' ', text)  # remove special characters
    text = text.strip()
    return text

df['subject_clean'] = df['subject'].apply(clean_text)
df['category_clean'] = df['category'].apply(clean_text)

# =====================================================
# 2b. Handle multiple origins
# =====================================================
# Split multiple origins by comma, then join back with ';' to keep as single string for TE
def preprocess_origin(orig):
    if pd.isna(orig) or orig == "missing":
        return "missing"
    parts = [o.strip() for o in str(orig).split(',')]
    return ';'.join(parts)

df['origin'] = df['origin'].apply(preprocess_origin)

# =====================================================
# 3. SentenceTransformer Embedding
# =====================================================
model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(model_name)

def embed_column(series):
    return embedder.encode(series.tolist(), convert_to_numpy=True)

print("Generating embeddings for:", text_cols)

embedding_features = []
for col in ['subject_clean', 'category_clean']:
    emb = embed_column(df[col])
    emb_df = pd.DataFrame(
        emb,
        columns=[f"{col}_emb_{i}" for i in range(emb.shape[1])]
    )
    embedding_features.append(emb_df)

embedding_df = pd.concat(embedding_features, axis=1)

# Optional PCA to reduce dimensions
pca = PCA(n_components=100, random_state=42)
embedding_df_pca = pd.DataFrame(
    pca.fit_transform(embedding_df),
    columns=[f"emb_pca_{i}" for i in range(100)]
)

# =====================================================
# 4. Smoothed Target Encoding
# =====================================================
print("Applying Smoothed Target Encoding:", target_encoding_cols)
te = TargetEncoder(cols=target_encoding_cols, smoothing=10)
target_encoded_df = te.fit_transform(df[target_encoding_cols], df[TARGET])

# =====================================================
# 5. One-Hot Encoding
# =====================================================
print("Applying One-Hot Encoding:", onehot_cols)
ohe = OneHotEncoder(drop="first", sparse_output=False)
ohe_array = ohe.fit_transform(df[onehot_cols])
ohe_df = pd.DataFrame(
    ohe_array,
    columns=ohe.get_feature_names_out(onehot_cols)
)

# =====================================================
# 6. Combine all engineered features
# =====================================================
X = pd.concat([embedding_df_pca, target_encoded_df, ohe_df], axis=1)
y = df[TARGET]

print("Final feature matrix shape:", X.shape)

# =====================================================
# 7. Sanitize feature names for XGBoost compatibility
# =====================================================
X.columns = (
    X.columns
      .str.replace(r'[\[\]\{\}\:\"\'\,]', '_', regex=True)
      .str.replace(r'[^A-Za-z0-9_]+', '_', regex=True)
)
# Out:
# Generating embeddings for: ['subject', 'category']
# Applying Smoothed Target Encoding: ['notifying_country', 'origin']
# Applying One-Hot Encoding: ['classification', 'Hazard_Type']
# Final feature matrix shape: (27397, 114)

# %%
# =====================================================
# 7. Train/Test Split
# =====================================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# ============================================
# Recreate model with best parameters
# ============================================
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    device='cuda',
    predictor='gpu_predictor',
    random_state=42,
    n_estimators=500,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    min_child_weight=1,
    reg_alpha=1,    # L1 regularization
    reg_lambda=2    # L2 regularization
)

# ============================================
# Fit on training data
# ============================================
xgb_model.fit(X_train, y_train)

# ============================================
# Predict on training data (optional, for quick evaluation)
# ============================================
y_train_pred = xgb_model.predict(X_train)
print("=== Training Data Performance ===")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))

# ============================================
# Predict on test data
# ============================================
y_test_pred = xgb_model.predict(X_test)
print("=== Test Data Performance ===")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:07:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Training Data Performance ===
# Accuracy: 0.9191218647337956
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      8848
#            1       0.91      0.95      0.93     10329
#
#     accuracy                           0.92     19177
#    macro avg       0.92      0.92      0.92     19177
# weighted avg       0.92      0.92      0.92     19177
#
# === Test Data Performance ===
# Accuracy: 0.8648418491484184
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      3793
#            1       0.85      0.90      0.88      4427
#
#     accuracy                           0.86      8220
#    macro avg       0.87      0.86      0.86      8220
# weighted avg       0.87      0.86      0.86      8220

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# ============================================
# 1. Recreate XGBoost model with tuned parameters
# ============================================
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',       # histogram-based tree, GPU compatible
    device='cuda',            # GPU device
    random_state=42,
    n_estimators=1000,        # moderate number of trees
    max_depth=5,              # balanced depth to reduce overfitting
    learning_rate=0.03,       # slower learning rate for stability
    subsample=0.8,            # row sampling
    colsample_bytree=0.8,     # feature sampling
    gamma=0.1,                # minimal loss reduction for split
    min_child_weight=5,       # reduce sensitivity to noise
    reg_alpha=0.5,            # L1 regularization
    reg_lambda=1.0            # L2 regularization
)

# ============================================
# 2. Fit model on training data
# ============================================
xgb_model.fit(X_train, y_train)

# ============================================
# 3. Evaluate on training data
# ============================================
y_train_pred = xgb_model.predict(X_train)
print("=== Training Data Performance ===")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))

# ============================================
# 4. Evaluate on test data
# ============================================
y_test_pred = xgb_model.predict(X_test)
print("=== Test Data Performance ===")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# === Training Data Performance ===
# Accuracy: 0.9593262762684466
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      8848
#            1       0.95      0.98      0.96     10329
#
#     accuracy                           0.96     19177
#    macro avg       0.96      0.96      0.96     19177
# weighted avg       0.96      0.96      0.96     19177
#
# === Test Data Performance ===
# Accuracy: 0.8710462287104623
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      3793
#            1       0.86      0.91      0.88      4427
#
#     accuracy                           0.87      8220
#    macro avg       0.87      0.87      0.87      8220
# weighted avg       0.87      0.87      0.87      8220

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from category_encoders import TargetEncoder
from sentence_transformers import SentenceTransformer

# =====================================================
# 1. Recode target
# =====================================================
def recode_risk(risk):
    if risk in ['no risk', 'not serious', 'potential risk', 'undecided', 'potentially serious']:
        return 0
    elif risk == 'serious':
        return 1
    else:
        return -1

df["risk_decision_2class"] = df["risk_decision"].apply(recode_risk)
df = df[df["risk_decision_2class"] != -1]
TARGET = "risk_decision_2class"

# =====================================================
# 2. Define feature groups
# =====================================================
embedding_cols = ["subject"]
onehot_cols = ["category", "classification", "Hazard_Type"]
target_encoding_cols = ["notifying_country", "origin"]

# Fill missing
for col in embedding_cols + onehot_cols + target_encoding_cols:
    df[col] = df[col].fillna("missing")

# =====================================================
# 2a. Group rare categories for target encoding
# =====================================================
for col in target_encoding_cols:
    counts = df[col].value_counts()
    rare = counts[counts < 50].index
    df[col] = df[col].replace(rare, 'other')

# =====================================================
# 3. Subject Embeddings
# =====================================================
model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(model_name)

def embed_column(series):
    return embedder.encode(series.tolist(), convert_to_numpy=True)

print("Generating embeddings for:", embedding_cols)
embedding_features = []
for col in embedding_cols:
    emb = embed_column(df[col])
    emb_df = pd.DataFrame(
        emb,
        columns=[f"{col}_emb_{i}" for i in range(emb.shape[1])]
    )
    embedding_features.append(emb_df)

embedding_df = pd.concat(embedding_features, axis=1)

# Reduce dimension using PCA
pca = PCA(n_components=100, random_state=42)
subject_emb_pca = pca.fit_transform(embedding_df.filter(like='subject_emb'))
embedding_df_pca = pd.DataFrame(subject_emb_pca, columns=[f'subject_emb_{i}' for i in range(100)])

# =====================================================
# 4. Smoothed Target Encoding
# =====================================================
print("Applying Smoothed Target Encoding:", target_encoding_cols)
te = TargetEncoder(cols=target_encoding_cols, smoothing=10)
target_encoded_df = te.fit_transform(df[target_encoding_cols], df[TARGET])

# =====================================================
# 5. One-Hot Encoding
# =====================================================
print("Applying One-Hot Encoding:", onehot_cols)
ohe = OneHotEncoder(drop="first", sparse_output=False)
ohe_array = ohe.fit_transform(df[onehot_cols])
ohe_df = pd.DataFrame(
    ohe_array,
    columns=ohe.get_feature_names_out(onehot_cols)
)

# =====================================================
# 6. Combine all engineered features
# =====================================================
X = pd.concat([embedding_df_pca, target_encoded_df, ohe_df], axis=1)
y = df[TARGET]

print("Final feature matrix shape:", X.shape)

# =====================================================
# 7. Sanitize feature names for XGBoost compatibility
# =====================================================
X.columns = (
    X.columns
      .str.replace(r'[\[\]\{\}\:\"\'\,]', '_', regex=True)
      .str.replace(r'[^A-Za-z0-9_]+', '_', regex=True)
)

# =====================================================
# 8. Train/Test Split
# =====================================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print("Preprocessing complete. Ready for XGBoost training!")
# Out:
# Generating embeddings for: ['subject']
# Applying Smoothed Target Encoding: ['notifying_country', 'origin']
# Applying One-Hot Encoding: ['category', 'classification', 'Hazard_Type']
# Final feature matrix shape: (27397, 150)
# Preprocessing complete. Ready for XGBoost training!

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# ============================================
# Recreate model with best parameters
# ============================================
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    device='cuda',
    predictor='gpu_predictor',
    random_state=42,
    n_estimators=500,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    min_child_weight=1,
    reg_alpha=1,    # L1 regularization
    reg_lambda=2    # L2 regularization
)

# ============================================
# Fit on training data
# ============================================
xgb_model.fit(X_train, y_train)

# ============================================
# Predict on training data (optional, for quick evaluation)
# ============================================
y_train_pred = xgb_model.predict(X_train)
print("=== Training Data Performance ===")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))

# ============================================
# Predict on test data
# ============================================
y_test_pred = xgb_model.predict(X_test)
print("=== Test Data Performance ===")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:14:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Training Data Performance ===
# Accuracy: 0.9202690723262241
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      8848
#            1       0.91      0.95      0.93     10329
#
#     accuracy                           0.92     19177
#    macro avg       0.92      0.92      0.92     19177
# weighted avg       0.92      0.92      0.92     19177
#
# === Test Data Performance ===
# Accuracy: 0.8658150851581509
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      3793
#            1       0.86      0.90      0.88      4427
#
#     accuracy                           0.87      8220
#    macro avg       0.87      0.86      0.86      8220
# weighted avg       0.87      0.87      0.87      8220
